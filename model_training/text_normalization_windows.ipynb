# %%
import tensorflow as tf
 
import time
import numpy as np

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
import re

# %%
os.mkdir('second_randomized')

# %%
os.chdir('second_randomized')

# %%
# !cp -rav /gdrive/MyDrive/ywl_transformer/second_randomized/* /content/second_randomized/
# Out:
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints' -> '/content/second_randomized/checkpoints'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/baseline' -> '/content/second_randomized/checkpoints/baseline'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/baseline/train' -> '/content/second_randomized/checkpoints/baseline/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/baseline/train/ckpt-37.index' -> '/content/second_randomized/checkpoints/baseline/train/ckpt-37.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/baseline/train/ckpt-38.index' -> '/content/second_randomized/checkpoints/baseline/train/ckpt-38.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/baseline/train/ckpt-36.index' -> '/content/second_randomized/checkpoints/baseline/train/ckpt-36.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/baseline/train/ckpt-39.index' -> '/content/second_randomized/checkpoints/baseline/train/ckpt-39.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/baseline/train/ckpt-40.index' -> '/content/second_randomized/checkpoints/baseline/train/ckpt-40.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/baseline/train/ckpt-39.data-00000-of-00001' -> '/content/second_randomized/checkpoints/baseline/train/ckpt-39.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/baseline/train/ckpt-37.data-00000-of-00001' -> '/content/second_randomized/checkpoints/baseline/train/ckpt-37.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/baseline/train/ckpt-38.data-00000-of-00001' -> '/content/second_randomized/checkpoints/baseline/train/ckpt-38.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/baseline/train/ckpt-40.data-00000-of-00001' -> '/content/second_randomized/checkpoints/baseline/train/ckpt-40.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/baseline/train/ckpt-36.data-00000-of-00001' -> '/content/second_randomized/checkpoints/baseline/train/ckpt-36.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/baseline/train/checkpoint' -> '/content/second_randomized/checkpoints/baseline/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/left_aligned' -> '/content/second_randomized/checkpoints/left_aligned'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/left_aligned/train' -> '/content/second_randomized/checkpoints/left_aligned/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/left_aligned/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/left_aligned/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/left_aligned/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/left_aligned/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/left_aligned/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/left_aligned/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/left_aligned/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/left_aligned/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/left_aligned/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/left_aligned/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/left_aligned/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/left_aligned/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/left_aligned/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/left_aligned/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/left_aligned/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/left_aligned/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/left_aligned/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/left_aligned/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/left_aligned/train/checkpoint' -> '/content/second_randomized/checkpoints/left_aligned/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/left_aligned/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/left_aligned/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_aligned' -> '/content/second_randomized/checkpoints/right_aligned'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_aligned/train' -> '/content/second_randomized/checkpoints/right_aligned/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_aligned/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/right_aligned/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_aligned/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/right_aligned/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_aligned/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/right_aligned/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_aligned/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/right_aligned/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_aligned/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_aligned/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_aligned/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_aligned/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_aligned/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_aligned/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_aligned/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_aligned/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_aligned/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/right_aligned/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_aligned/train/checkpoint' -> '/content/second_randomized/checkpoints/right_aligned/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_aligned/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_aligned/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_3_window' -> '/content/second_randomized/checkpoints/sliding_3_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_3_window/train' -> '/content/second_randomized/checkpoints/sliding_3_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_3_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/sliding_3_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_3_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/sliding_3_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_3_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/sliding_3_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_3_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_3_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_3_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_3_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_3_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_3_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_3_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_3_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_3_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/sliding_3_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_3_window/train/checkpoint' -> '/content/second_randomized/checkpoints/sliding_3_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_3_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/sliding_3_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_3_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_3_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_5_window' -> '/content/second_randomized/checkpoints/sliding_5_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_5_window/train' -> '/content/second_randomized/checkpoints/sliding_5_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_5_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/sliding_5_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_5_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_5_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_5_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/sliding_5_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_5_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/sliding_5_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_5_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_5_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_5_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_5_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_5_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_5_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_5_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/sliding_5_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_5_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/sliding_5_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_5_window/train/checkpoint' -> '/content/second_randomized/checkpoints/sliding_5_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_5_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_5_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_window' -> '/content/second_randomized/checkpoints/sliding_7_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_window/train' -> '/content/second_randomized/checkpoints/sliding_7_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_7_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/sliding_7_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/sliding_7_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_7_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_7_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/sliding_7_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/sliding_7_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/sliding_7_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_7_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_window/train/checkpoint' -> '/content/second_randomized/checkpoints/sliding_7_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_7_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_window' -> '/content/second_randomized/checkpoints/sliding_9_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_window/train' -> '/content/second_randomized/checkpoints/sliding_9_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_9_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/sliding_9_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_9_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/sliding_9_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_9_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/sliding_9_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_9_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/sliding_9_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_9_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/sliding_9_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_window/train/checkpoint' -> '/content/second_randomized/checkpoints/sliding_9_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_11_window' -> '/content/second_randomized/checkpoints/sliding_11_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_11_window/train' -> '/content/second_randomized/checkpoints/sliding_11_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_11_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_11_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_11_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/sliding_11_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_11_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_11_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_11_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/sliding_11_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_11_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_11_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_11_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/sliding_11_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_11_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_11_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_11_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/sliding_11_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_11_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_11_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_11_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/sliding_11_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_11_window/train/checkpoint' -> '/content/second_randomized/checkpoints/sliding_11_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_13_window' -> '/content/second_randomized/checkpoints/sliding_13_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_13_window/train' -> '/content/second_randomized/checkpoints/sliding_13_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_13_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_13_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_13_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/sliding_13_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_13_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_13_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_13_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/sliding_13_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_13_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_13_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_13_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/sliding_13_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_13_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_13_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_13_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/sliding_13_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_13_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_13_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_13_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/sliding_13_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_13_window/train/checkpoint' -> '/content/second_randomized/checkpoints/sliding_13_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_left_window' -> '/content/second_randomized/checkpoints/base_left_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_left_window/train' -> '/content/second_randomized/checkpoints/base_left_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_left_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_left_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_left_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/base_left_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_left_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_left_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_left_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/base_left_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_left_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_left_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_left_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/base_left_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_left_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_left_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_left_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/base_left_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_left_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_left_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_left_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/base_left_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_left_window/train/checkpoint' -> '/content/second_randomized/checkpoints/base_left_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_right_window' -> '/content/second_randomized/checkpoints/base_right_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_right_window/train' -> '/content/second_randomized/checkpoints/base_right_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_right_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_right_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_right_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/base_right_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_right_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_right_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_right_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/base_right_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_right_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_right_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_right_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/base_right_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_right_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_right_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_right_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/base_right_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_right_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_right_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_right_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/base_right_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_right_window/train/checkpoint' -> '/content/second_randomized/checkpoints/base_right_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_3_window' -> '/content/second_randomized/checkpoints/base_sliding_3_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_3_window/train' -> '/content/second_randomized/checkpoints/base_sliding_3_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/base_sliding_3_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_3_window/train/checkpoint' -> '/content/second_randomized/checkpoints/base_sliding_3_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_5_window' -> '/content/second_randomized/checkpoints/base_sliding_5_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_5_window/train' -> '/content/second_randomized/checkpoints/base_sliding_5_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/base_sliding_5_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_5_window/train/checkpoint' -> '/content/second_randomized/checkpoints/base_sliding_5_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_7_window' -> '/content/second_randomized/checkpoints/base_sliding_7_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_7_window/train' -> '/content/second_randomized/checkpoints/base_sliding_7_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/base_sliding_7_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_7_window/train/checkpoint' -> '/content/second_randomized/checkpoints/base_sliding_7_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_9_window' -> '/content/second_randomized/checkpoints/base_sliding_9_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_9_window/train' -> '/content/second_randomized/checkpoints/base_sliding_9_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/base_sliding_9_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_9_window/train/checkpoint' -> '/content/second_randomized/checkpoints/base_sliding_9_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_11_window' -> '/content/second_randomized/checkpoints/base_sliding_11_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_11_window/train' -> '/content/second_randomized/checkpoints/base_sliding_11_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_11_window/train/checkpoint' -> '/content/second_randomized/checkpoints/base_sliding_11_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_13_window' -> '/content/second_randomized/checkpoints/base_sliding_13_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_13_window/train' -> '/content/second_randomized/checkpoints/base_sliding_13_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/base_sliding_13_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_13_window/train/checkpoint' -> '/content/second_randomized/checkpoints/base_sliding_13_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_left_window' -> '/content/second_randomized/checkpoints/right_window_left_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_left_window/train' -> '/content/second_randomized/checkpoints/right_window_left_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_left_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_left_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_left_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/right_window_left_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_left_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_left_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_left_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/right_window_left_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_left_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_left_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_left_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/right_window_left_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_left_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_left_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_left_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/right_window_left_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_left_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_left_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_left_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/right_window_left_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_left_window/train/checkpoint' -> '/content/second_randomized/checkpoints/right_window_left_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_3' -> '/content/second_randomized/checkpoints/right_window_sliding_3'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_3/train' -> '/content/second_randomized/checkpoints/right_window_sliding_3/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/right_window_sliding_3/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_3/train/checkpoint' -> '/content/second_randomized/checkpoints/right_window_sliding_3/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_5' -> '/content/second_randomized/checkpoints/right_window_sliding_5'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_5/train' -> '/content/second_randomized/checkpoints/right_window_sliding_5/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_5/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_5/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_5/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/right_window_sliding_5/train/ckpt-16.index'
# ...
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_11/train' -> '/content/second_randomized/checkpoints/right_window_sliding_11/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/right_window_sliding_11/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_11/train/checkpoint' -> '/content/second_randomized/checkpoints/right_window_sliding_11/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_13' -> '/content/second_randomized/checkpoints/right_window_sliding_13'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_13/train' -> '/content/second_randomized/checkpoints/right_window_sliding_13/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/right_window_sliding_13/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_window_sliding_13/train/checkpoint' -> '/content/second_randomized/checkpoints/right_window_sliding_13/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_left_window' -> '/content/second_randomized/checkpoints/sliding_7_left_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_left_window/train' -> '/content/second_randomized/checkpoints/sliding_7_left_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/sliding_7_left_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_7_left_window/train/checkpoint' -> '/content/second_randomized/checkpoints/sliding_7_left_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_left_window' -> '/content/second_randomized/checkpoints/sliding_9_left_window'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_left_window/train' -> '/content/second_randomized/checkpoints/sliding_9_left_window/train'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-16.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-16.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-16.index' -> '/content/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-16.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-17.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-17.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-17.index' -> '/content/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-17.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-18.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-18.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-18.index' -> '/content/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-18.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-19.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-19.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-19.index' -> '/content/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-19.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-20.data-00000-of-00001' -> '/content/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-20.data-00000-of-00001'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-20.index' -> '/content/second_randomized/checkpoints/sliding_9_left_window/train/ckpt-20.index'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/sliding_9_left_window/train/checkpoint' -> '/content/second_randomized/checkpoints/sliding_9_left_window/train/checkpoint'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/left_window_in_padded_20_corr.pkl' -> '/content/second_randomized/left_window_in_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/left_window_out_padded_20_corr.pkl' -> '/content/second_randomized/left_window_out_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/right_window_in_padded_20_corr.pkl' -> '/content/second_randomized/right_window_in_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/right_window_out_padded_20_corr.pkl' -> '/content/second_randomized/right_window_out_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/sliding_in_11_padded_20_corr.pkl' -> '/content/second_randomized/sliding_in_11_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/sliding_in_13_padded_20_corr.pkl' -> '/content/second_randomized/sliding_in_13_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/sliding_in_3_padded_20_corr.pkl' -> '/content/second_randomized/sliding_in_3_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/sliding_in_5_padded_20_corr.pkl' -> '/content/second_randomized/sliding_in_5_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/sliding_in_7_padded_20_corr.pkl' -> '/content/second_randomized/sliding_in_7_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/sliding_in_9_padded_20_corr.pkl' -> '/content/second_randomized/sliding_in_9_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/sliding_out_11_padded_20_corr.pkl' -> '/content/second_randomized/sliding_out_11_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/sliding_out_13_padded_20_corr.pkl' -> '/content/second_randomized/sliding_out_13_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/sliding_out_3_padded_20_corr.pkl' -> '/content/second_randomized/sliding_out_3_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/sliding_out_5_padded_20_corr.pkl' -> '/content/second_randomized/sliding_out_5_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/sliding_out_7_padded_20_corr.pkl' -> '/content/second_randomized/sliding_out_7_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/sliding_out_9_padded_20_corr.pkl' -> '/content/second_randomized/sliding_out_9_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/test_in_padded_20_corr.pkl' -> '/content/second_randomized/test_in_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/test_out_padded_20_corr.pkl' -> '/content/second_randomized/test_out_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 10 preprocess.txt' -> '/content/second_randomized/text 10 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 11 preprocess.txt' -> '/content/second_randomized/text 11 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 12 preprocess.txt' -> '/content/second_randomized/text 12 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 13 preprocess.txt' -> '/content/second_randomized/text 13 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 14 preprocess.txt' -> '/content/second_randomized/text 14 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 15 preprocess.txt' -> '/content/second_randomized/text 15 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 16 preprocess.txt' -> '/content/second_randomized/text 16 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 17 preprocess.txt' -> '/content/second_randomized/text 17 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 18 preprocess.txt' -> '/content/second_randomized/text 18 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 19 preprocess.txt' -> '/content/second_randomized/text 19 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 1 preprocess.txt' -> '/content/second_randomized/text 1 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 20 preprocess.txt' -> '/content/second_randomized/text 20 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 2 preprocess.txt' -> '/content/second_randomized/text 2 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 3 preprocess.txt' -> '/content/second_randomized/text 3 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 4 preprocess.txt' -> '/content/second_randomized/text 4 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 5 preprocess.txt' -> '/content/second_randomized/text 5 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 6 preprocess.txt' -> '/content/second_randomized/text 6 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 7 preprocess.txt' -> '/content/second_randomized/text 7 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 8 preprocess.txt' -> '/content/second_randomized/text 8 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/text 9 preprocess.txt' -> '/content/second_randomized/text 9 preprocess.txt'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/total_vocab_20.pkl' -> '/content/second_randomized/total_vocab_20.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/train_in_padded_20_corr.pkl' -> '/content/second_randomized/train_in_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/train_out_padded_20_corr.pkl' -> '/content/second_randomized/train_out_padded_20_corr.pkl'
# '/gdrive/MyDrive/ywl_transformer/second_randomized/vocab.csv' -> '/content/second_randomized/vocab.csv'

# %%
# three types of sliding window:
#  1) left_slide: left-aligned with sliding right edge
#  2) right_slide: right-aligned with sliding left edge
#  3) lim_slide: sliding window absolutely throughout to end of each text
#     lim: side of sliding window
#     split_comma: split on commas rather than periods
 
def retrieve_sents(data_stream, 
                   left_slide=False, 
                   right_slide=False, 
                   lim_slide=False, 
                   split_comma=False, 
                   lim=0):
  sents = []
  current_sent = []
  slides = {}
  for i in range(lim):
    slides[i] = []
  for j, item in enumerate(data_stream):
    current_sent.append(item)
    if lim_slide == True:
      if j < lim:
        # j + 1 because otherwise initial sequences would have len > lim
        for i in range(j + 1):
          slides[i].append(item)
      # currently, this doesn't handle the last several instances correctly
      else:
        # check modulo, and add to sents, and clear dict entry
        current_slide = j % lim
        sents.append(slides[current_slide])
        slides[current_slide] = []
        # then add current word to all dict entries
        for i in range(lim):
          slides[i].append(item)
    else:
      if split_comma:
        split = ['.', ',']
      else:
        split = ['.']
      if item[0] in split:
        if len(current_sent) >= 3:
          # handle aligned versions
          if left_slide == True:
            sent_windows = []
            for i in range(len(current_sent) - 1, 1, -1):
              sent_windows.append(current_sent[:i])
            sents += sent_windows
          if right_slide == True:
            sent_windows = []
            for i in range(1, len(current_sent) - 1):
              sent_windows.append(current_sent[i:])
            sents += sent_windows
 
        # handle the basic current_sent in any case
        if len(current_sent) >= 2:
          sents.append(current_sent)
          current_sent = []
        else:
          current_sent = [] # clear single stray instance of comma or period
  
  # append whatever is left over at the end of a text (if no final comma or
  #  period); if lim_slide, only include the last complete unit
  if lim_slide == True:
    for i in range(lim):
      if len(slides[i]) == lim:
        sents.append(slides[i])
  else:
    if current_sent != []:
      sents.append(current_sent)
  return sents
 
def join_sents(sent_list):
  # sents are sequences of units like this: '.\t.\t[punc]\t100%\n'
  input_sents = []
  output_sents = []
  for sent in sent_list:
    input_sent = []
    output_sent = []
    for word in sent:
      split_word = word.strip('\n').split('\t')
      if len(split_word) > 1:
        output_sent.append(split_word[1])
      input_sent.append(split_word[0])
    input_ = re.sub('&', '', ' '.join(input_sent))
    input_ = re.sub('% ', '', input_)
    input_ = re.sub('%', '', input_)
    input_sents.append(input_)
    output_sents.append(' '.join(output_sent))
  return input_sents, output_sents

# %%
# sliding data could be of many different sizes
data = []
left_window_data = []
right_window_data = []
sliding_3_data = []
sliding_5_data = []
sliding_7_data = []
sliding_9_data = []
sliding_11_data = []
sliding_13_data = []
test_data = []

test_text_indices = [5, 10, 17, 18]
training_text_indices = [i for i in range(1, 21) if i not in test_text_indices]


for i in training_text_indices:
    f = open('text ' + str(i) + ' preprocess.txt', 'r')
    item_stream = f.readlines()
    f.close()
        
    data += retrieve_sents(item_stream, split_comma=True)
    left_window_data += retrieve_sents(item_stream, left_slide=True, split_comma=True)
    right_window_data += retrieve_sents(item_stream, right_slide=True, split_comma=True)
    sliding_3_data += retrieve_sents(item_stream, lim_slide=True, lim=3)
    sliding_5_data += retrieve_sents(item_stream, lim_slide=True, lim=5)
    sliding_7_data += retrieve_sents(item_stream, lim_slide=True, lim=7)
    sliding_9_data += retrieve_sents(item_stream, lim_slide=True, lim=9)
    sliding_11_data += retrieve_sents(item_stream, lim_slide=True, lim=11)
    sliding_13_data += retrieve_sents(item_stream, lim_slide=True, lim=13)
        
for i in test_text_indices:
    f = open('text ' + str(i) + ' preprocess.txt', 'r')
    item_stream = f.readlines()
    f.close()
        
    test_data += retrieve_sents(item_stream, split_comma=True)

# %%
train_input, train_output = join_sents(data)
left_window_input, left_window_output = join_sents(left_window_data)
right_window_input, right_window_output = join_sents(right_window_data)
sliding_3_input, sliding_3_output = join_sents(sliding_3_data)
sliding_5_input, sliding_5_output = join_sents(sliding_5_data)
sliding_7_input, sliding_7_output = join_sents(sliding_7_data)
sliding_9_input, sliding_9_output = join_sents(sliding_9_data)
sliding_11_input, sliding_11_output = join_sents(sliding_11_data)
sliding_13_input, sliding_13_output = join_sents(sliding_13_data)
test_input, test_output = join_sents(test_data)

# %%
train_in_tokens = [[c for c in line] for line in train_input]
train_out_tokens = [line.split(' ') for line in train_output]
left_window_in_tokens = [[c for c in line] for line in left_window_input]
left_window_out_tokens = [line.split(' ') for line in left_window_output]
right_window_in_tokens = [[c for c in line] for line in right_window_input]
right_window_out_tokens = [line.split(' ') for line in right_window_output]
sliding_in_3_tokens = [[c for c in line] for line in sliding_3_input]
sliding_out_3_tokens = [line.split(' ') for line in sliding_3_output]
sliding_in_5_tokens = [[c for c in line] for line in sliding_5_input]
sliding_out_5_tokens = [line.split(' ') for line in sliding_5_output]
sliding_in_7_tokens = [[c for c in line] for line in sliding_7_input]
sliding_out_7_tokens = [line.split(' ') for line in sliding_7_output]
sliding_in_9_tokens = [[c for c in line] for line in sliding_9_input]
sliding_out_9_tokens = [line.split(' ') for line in sliding_9_output]
sliding_in_11_tokens = [[c for c in line] for line in sliding_11_input]
sliding_out_11_tokens = [line.split(' ') for line in sliding_11_output]
sliding_in_13_tokens = [[c for c in line] for line in sliding_13_input]
sliding_out_13_tokens = [line.split(' ') for line in sliding_13_output]
test_in_tokens = [[c for c in line] for line in test_input]
test_out_tokens = [line.split(' ') for line in test_output]

# %%
# filters out empty strings
train_out_tokens = [[w for w in line if w != ''] for line in train_out_tokens]

# %%
# with 20 documents
# 6.6534 repeating
# with randomized results: 7.751824817 repeating
sum([len(i) for i in test_out_tokens])/len(test_out_tokens)
# Out:
# 7.455830388692579

# %%
input_tokens = [[c for c in line] for line in train_input + test_input]
output_tokens = [line.split(' ') for line in train_output + test_output]

# %%
# generates vocabulary set
import io
import pandas as pd

vocab_df = pd.read_csv('vocab.csv', delimiter='\t')
vocab = vocab_df['word'].dropna().to_numpy().tolist()

# %%
charset = set([c for line in train_input+test_input for c in line])
wordset = list(set([w for line in train_output+test_output for w in line.split(' ')])) + vocab

complete_set = charset.union(wordset)

complete_set = ['<pad>'] + list(complete_set) + ['<start>', '<end>']

total_vocab = {k: i for (i, k) in enumerate(complete_set)}

inv_total_vocab = {i: k for (k, i) in total_vocab.items()}

# %%
import pickle

# %%
# loads pregenerated vocabulary
total_vocab = pickle.load(open('total_vocab_20.pkl', 'rb'))

# %%
inv_total_vocab = {i: k for (k, i) in total_vocab.items()}

# %%
BATCH_SIZE = 64

# %%
# add a start and end token to the input and target
def encode(lang1, lang2):
  start_token = total_vocab['<start>']
  end_token = total_vocab['<end>']
  lang1 = [start_token] + [total_vocab[w] for w in lang1] \
           + [end_token]

  lang2 = [start_token] + [total_vocab[w] for w in lang2] \
           + [end_token]
  
  return lang1, lang2

# %%
train_in_encoded, train_out_encoded = zip(*[encode(a, b) for a, b in zip(train_in_tokens, train_out_tokens)])
left_window_in_encoded, left_window_out_encoded = zip(*[encode(a, b) for a, b in zip(left_window_in_tokens, left_window_out_tokens)])
right_window_in_encoded, right_window_out_encoded = zip(*[encode(a, b) for a, b in zip(right_window_in_tokens, right_window_out_tokens)])
sliding_in_3_encoded, sliding_out_3_encoded = zip(*[encode(a, b) for a, b in zip(sliding_in_3_tokens, sliding_out_3_tokens)])
sliding_in_5_encoded, sliding_out_5_encoded = zip(*[encode(a, b) for a, b in zip(sliding_in_5_tokens, sliding_out_5_tokens)])
sliding_in_7_encoded, sliding_out_7_encoded = zip(*[encode(a, b) for a, b in zip(sliding_in_7_tokens, sliding_out_7_tokens)])
sliding_in_9_encoded, sliding_out_9_encoded = zip(*[encode(a, b) for a, b in zip(sliding_in_9_tokens, sliding_out_9_tokens)])
sliding_in_11_encoded, sliding_out_11_encoded = zip(*[encode(a, b) for a, b in zip(sliding_in_11_tokens, sliding_out_11_tokens)])
sliding_in_13_encoded, sliding_out_13_encoded = zip(*[encode(a, b) for a, b in zip(sliding_in_13_tokens, sliding_out_13_tokens)])
test_in_encoded, test_out_encoded = zip(*[encode(a, b) for a, b in zip(test_in_tokens, test_out_tokens)])

# %%
INPUT_LEN = max([len(line) for line in train_in_encoded] + \
                [len(line) for line in left_window_in_encoded] + \
                [len(line) for line in right_window_in_encoded] + \
                [len(line) for line in test_in_encoded])
OUTPUT_LEN = max([len(line) for line in train_out_encoded] + \
                [len(line) for line in left_window_out_encoded] + \
                [len(line) for line in right_window_out_encoded] + \
                [len(line) for line in test_out_encoded])

# %%
print(INPUT_LEN)
print(OUTPUT_LEN)
# Out:
# 273
# 36

# %%
# for use in later testing
INPUT_LEN = 273
OUTPUT_LEN = 36

# %%
# pad sequences
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
train_in_padded = pad_sequences(train_in_encoded, 
                             maxlen=INPUT_LEN,
                             padding='post', 
                             value=total_vocab['<pad>'])
left_window_in_padded = pad_sequences(left_window_in_encoded, 
                             maxlen=INPUT_LEN,
                             padding='post', 
                             value=total_vocab['<pad>'])
right_window_in_padded = pad_sequences(right_window_in_encoded, 
                             maxlen=INPUT_LEN,
                             padding='post', 
                             value=total_vocab['<pad>'])
sliding_in_3_padded = pad_sequences(sliding_in_3_encoded, 
                             maxlen=INPUT_LEN,
                             padding='post', 
                             value=total_vocab['<pad>'])
sliding_in_5_padded = pad_sequences(sliding_in_5_encoded, 
                             maxlen=INPUT_LEN,
                             padding='post', 
                             value=total_vocab['<pad>'])
sliding_in_7_padded = pad_sequences(sliding_in_7_encoded, 
                             maxlen=INPUT_LEN,
                             padding='post', 
                             value=total_vocab['<pad>'])
sliding_in_9_padded = pad_sequences(sliding_in_9_encoded, 
                             maxlen=INPUT_LEN,
                             padding='post', 
                             value=total_vocab['<pad>'])
sliding_in_11_padded = pad_sequences(sliding_in_11_encoded, 
                             maxlen=INPUT_LEN,
                             padding='post', 
                             value=total_vocab['<pad>'])
sliding_in_13_padded = pad_sequences(sliding_in_13_encoded, 
                             maxlen=INPUT_LEN,
                             padding='post', 
                             value=total_vocab['<pad>'])
test_in_padded = pad_sequences(test_in_encoded, 
                             maxlen=INPUT_LEN,
                             padding='post', 
                             value=total_vocab['<pad>'])
train_out_padded = pad_sequences(train_out_encoded,
                             maxlen=OUTPUT_LEN,
                             padding='post',
                             value=total_vocab['<pad>'])
left_window_out_padded = pad_sequences(left_window_out_encoded,
                             maxlen=OUTPUT_LEN,
                             padding='post',
                             value=total_vocab['<pad>'])
right_window_out_padded = pad_sequences(right_window_out_encoded,
                             maxlen=OUTPUT_LEN,
                             padding='post',
                             value=total_vocab['<pad>'])
sliding_out_3_padded = pad_sequences(sliding_out_3_encoded,
                             maxlen=OUTPUT_LEN,
                             padding='post',
                             value=total_vocab['<pad>'])
sliding_out_5_padded = pad_sequences(sliding_out_5_encoded,
                             maxlen=OUTPUT_LEN,
                             padding='post',
                             value=total_vocab['<pad>'])
sliding_out_7_padded = pad_sequences(sliding_out_7_encoded,
                             maxlen=OUTPUT_LEN,
                             padding='post',
                             value=total_vocab['<pad>'])
sliding_out_9_padded = pad_sequences(sliding_out_9_encoded,
                             maxlen=OUTPUT_LEN,
                             padding='post',
                             value=total_vocab['<pad>'])
sliding_out_11_padded = pad_sequences(sliding_out_11_encoded,
                             maxlen=OUTPUT_LEN,
                             padding='post',
                             value=total_vocab['<pad>'])
sliding_out_13_padded = pad_sequences(sliding_out_13_encoded,
                             maxlen=OUTPUT_LEN,
                             padding='post',
                             value=total_vocab['<pad>'])
test_out_padded = pad_sequences(test_out_encoded,
                             maxlen=OUTPUT_LEN,
                             padding='post',
                             value=total_vocab['<pad>'])

# %%
# pickle datasets
pickle.dump(train_in_padded, open('train_in_padded_20_corr.pkl', 'wb'))
pickle.dump(train_out_padded, open('train_out_padded_20_corr.pkl', 'wb'))
pickle.dump(left_window_in_padded, open('left_window_in_padded_20_corr.pkl', 'wb'))
pickle.dump(left_window_out_padded, open('left_window_out_padded_20_corr.pkl', 'wb'))
pickle.dump(right_window_in_padded, open('right_window_in_padded_20_corr.pkl', 'wb'))
pickle.dump(right_window_out_padded, open('right_window_out_padded_20_corr.pkl', 'wb'))
pickle.dump(sliding_in_3_padded, open('sliding_in_3_padded_20_corr.pkl', 'wb'))
pickle.dump(sliding_out_3_padded, open('sliding_out_3_padded_20_corr.pkl', 'wb'))
pickle.dump(sliding_in_5_padded, open('sliding_in_5_padded_20_corr.pkl', 'wb'))
pickle.dump(sliding_out_5_padded, open('sliding_out_5_padded_20_corr.pkl', 'wb'))
pickle.dump(sliding_in_7_padded, open('sliding_in_7_padded_20_corr.pkl', 'wb'))
pickle.dump(sliding_out_7_padded, open('sliding_out_7_padded_20_corr.pkl', 'wb'))
pickle.dump(sliding_in_9_padded, open('sliding_in_9_padded_20_corr.pkl', 'wb'))
pickle.dump(sliding_out_9_padded, open('sliding_out_9_padded_20_corr.pkl', 'wb'))
pickle.dump(sliding_in_11_padded, open('sliding_in_11_padded_20_corr.pkl', 'wb'))
pickle.dump(sliding_out_11_padded, open('sliding_out_11_padded_20_corr.pkl', 'wb'))
pickle.dump(sliding_in_13_padded, open('sliding_in_13_padded_20_corr.pkl', 'wb'))
pickle.dump(sliding_out_13_padded, open('sliding_out_13_padded_20_corr.pkl', 'wb'))
pickle.dump(test_in_padded, open('test_in_padded_20_corr.pkl', 'wb'))
pickle.dump(test_out_padded, open('test_out_padded_20_corr.pkl', 'wb'))

# %%
# load picked datasets
train_in_padded = pickle.load(open('train_in_padded_20_corr.pkl', 'rb'))
train_out_padded = pickle.load(open('train_out_padded_20_corr.pkl', 'rb'))
left_window_in_padded = pickle.load(open('left_window_in_padded_20_corr.pkl', 'rb'))
left_window_out_padded = pickle.load(open('left_window_out_padded_20_corr.pkl', 'rb'))
right_window_in_padded = pickle.load(open('right_window_in_padded_20_corr.pkl', 'rb'))
right_window_out_padded = pickle.load(open('right_window_out_padded_20_corr.pkl', 'rb'))
sliding_in_3_padded = pickle.load(open('sliding_in_3_padded_20_corr.pkl', 'rb'))
sliding_out_3_padded = pickle.load(open('sliding_out_3_padded_20_corr.pkl', 'rb'))
sliding_in_5_padded = pickle.load(open('sliding_in_5_padded_20_corr.pkl', 'rb'))
sliding_out_5_padded = pickle.load(open('sliding_out_5_padded_20_corr.pkl', 'rb'))
sliding_in_7_padded = pickle.load(open('sliding_in_7_padded_20_corr.pkl', 'rb'))
sliding_out_7_padded = pickle.load(open('sliding_out_7_padded_20_corr.pkl', 'rb'))
sliding_in_9_padded = pickle.load(open('sliding_in_9_padded_20_corr.pkl', 'rb'))
sliding_out_9_padded = pickle.load(open('sliding_out_9_padded_20_corr.pkl', 'rb'))
sliding_in_11_padded = pickle.load(open('sliding_in_11_padded_20_corr.pkl', 'rb'))
sliding_out_11_padded = pickle.load(open('sliding_out_11_padded_20_corr.pkl', 'rb'))
sliding_in_13_padded = pickle.load(open('sliding_in_13_padded_20_corr.pkl', 'rb'))
sliding_out_13_padded = pickle.load(open('sliding_out_13_padded_20_corr.pkl', 'rb'))
test_in_padded = pickle.load(open('test_in_padded_20_corr.pkl', 'rb'))
test_out_padded = pickle.load(open('test_out_padded_20_corr.pkl', 'rb'))

# %%
# create TensorFlow datasets with data generated with different window types
# TODO: refactor the code in this cell
def create_tf_dataset(encoder_data, decoder_data):
  enc_numpy = np.asarray(encoder_data, dtype=np.int64)
  enc_dataset = tf.data.Dataset.from_tensor_slices(enc_numpy)
 
  dec_numpy = np.asarray(decoder_data, dtype=np.int64)
  dec_dataset = tf.data.Dataset.from_tensor_slices(dec_numpy)
 
  dataset = tf.data.Dataset.zip((enc_dataset, dec_dataset))
 
  dataset = dataset.cache()
  dataset = dataset.padded_batch(BATCH_SIZE)
  dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
 
  return dataset
 
# sliding datasets
sliding_3_dataset = create_tf_dataset(sliding_in_3_padded, sliding_out_3_padded)
sliding_5_dataset = create_tf_dataset(sliding_in_5_padded, sliding_out_5_padded)
sliding_7_dataset = create_tf_dataset(sliding_in_7_padded, sliding_out_7_padded)
sliding_9_dataset = create_tf_dataset(sliding_in_9_padded, sliding_out_9_padded)
sliding_11_dataset = create_tf_dataset(sliding_in_11_padded, sliding_out_11_padded)
sliding_13_dataset = create_tf_dataset(sliding_in_13_padded, sliding_out_13_padded)
 
# cache the dataset to memory to get a speedup while reading from it.
 
# non-window training data
enc_training_numpy = np.asarray(train_in_padded, dtype=np.int64)
enc_train_dataset = tf.data.Dataset.from_tensor_slices(enc_training_numpy)
 
dec_training_numpy = np.asarray(train_out_padded, dtype=np.int64)
dec_train_dataset = tf.data.Dataset.from_tensor_slices(dec_training_numpy)
 
train_dataset = tf.data.Dataset.zip((enc_train_dataset, dec_train_dataset))
 
train_dataset = train_dataset.cache()
train_dataset = train_dataset.padded_batch(BATCH_SIZE)
train_dataset = train_dataset.prefetch(tf.data.experimental.AUTOTUNE)
 
# left window data
enc_left_window_numpy = np.asarray(left_window_in_padded, dtype=np.int64)
enc_left_window_dataset = tf.data.Dataset.from_tensor_slices(enc_left_window_numpy)
 
dec_left_window_numpy = np.asarray(left_window_out_padded, dtype=np.int64)
dec_left_window_dataset = tf.data.Dataset.from_tensor_slices(dec_left_window_numpy)
 
left_window_dataset = tf.data.Dataset.zip((enc_left_window_dataset, dec_left_window_dataset))
 
left_window_dataset = left_window_dataset.cache()
left_window_dataset = left_window_dataset.padded_batch(BATCH_SIZE)
left_window_dataset = left_window_dataset.prefetch(tf.data.experimental.AUTOTUNE)
 
# right window data
enc_right_window_numpy = np.asarray(right_window_in_padded, dtype=np.int64)
enc_right_window_dataset = tf.data.Dataset.from_tensor_slices(enc_right_window_numpy)
 
dec_right_window_numpy = np.asarray(right_window_out_padded, dtype=np.int64)
dec_right_window_dataset = tf.data.Dataset.from_tensor_slices(dec_right_window_numpy)
 
right_window_dataset = tf.data.Dataset.zip((enc_right_window_dataset, dec_right_window_dataset))
 
right_window_dataset = right_window_dataset.cache()
right_window_dataset = right_window_dataset.padded_batch(BATCH_SIZE)
right_window_dataset = right_window_dataset.prefetch(tf.data.experimental.AUTOTUNE)
 
# hybrid datasets base + other
base_left_window_padded_enc = np.concatenate((train_in_padded, left_window_in_padded))
base_left_window_padded_dec = np.concatenate((train_out_padded, left_window_out_padded))
base_left_window_dataset = create_tf_dataset(base_left_window_padded_enc, base_left_window_padded_dec)
 
base_right_window_padded_enc = np.concatenate((train_in_padded, right_window_in_padded))
base_right_window_padded_dec = np.concatenate((train_out_padded, right_window_out_padded))
base_right_window_dataset = create_tf_dataset(base_right_window_padded_enc, base_right_window_padded_dec)
 
base_sliding_3_padded_enc = np.concatenate((train_in_padded, sliding_in_3_padded))
base_sliding_3_padded_dec = np.concatenate((train_out_padded, sliding_out_3_padded))
base_sliding_3_dataset = create_tf_dataset(base_sliding_3_padded_enc, base_sliding_3_padded_dec)
 
base_sliding_5_padded_enc = np.concatenate((train_in_padded, sliding_in_5_padded))
base_sliding_5_padded_dec = np.concatenate((train_out_padded, sliding_out_5_padded))
base_sliding_5_dataset = create_tf_dataset(base_sliding_5_padded_enc, base_sliding_5_padded_dec)
 
base_sliding_7_padded_enc = np.concatenate((train_in_padded, sliding_in_7_padded))
base_sliding_7_padded_dec = np.concatenate((train_out_padded, sliding_out_7_padded))
base_sliding_7_dataset = create_tf_dataset(base_sliding_7_padded_enc, base_sliding_7_padded_dec)
 
base_sliding_9_padded_enc = np.concatenate((train_in_padded, sliding_in_9_padded))
base_sliding_9_padded_dec = np.concatenate((train_out_padded, sliding_out_9_padded))
base_sliding_9_dataset = create_tf_dataset(base_sliding_9_padded_enc, base_sliding_9_padded_dec)
 
base_sliding_11_padded_enc = np.concatenate((train_in_padded, sliding_in_11_padded))
base_sliding_11_padded_dec = np.concatenate((train_out_padded, sliding_out_11_padded))
base_sliding_11_dataset = create_tf_dataset(base_sliding_11_padded_enc, base_sliding_11_padded_dec)
 
base_sliding_13_padded_enc = np.concatenate((train_in_padded, sliding_in_13_padded))
base_sliding_13_padded_dec = np.concatenate((train_out_padded, sliding_out_13_padded))
base_sliding_13_dataset = create_tf_dataset(base_sliding_13_padded_enc, base_sliding_13_padded_dec)
 
# hybrid datasets right_window + other
right_window_left_window_padded_enc = np.concatenate((right_window_in_padded,
                                                      left_window_in_padded))
right_window_left_window_padded_dec = np.concatenate((right_window_out_padded,
                                                      left_window_out_padded))
right_window_left_window_dataset = create_tf_dataset(right_window_left_window_padded_enc,
                                                     right_window_left_window_padded_dec)
 
right_window_sliding_3_padded_enc = np.concatenate((right_window_in_padded,
                                                    sliding_in_3_padded))
right_window_sliding_3_padded_dec = np.concatenate((right_window_out_padded,
                                                    sliding_out_3_padded))
right_window_sliding_3_dataset = create_tf_dataset(right_window_sliding_3_padded_enc,
                                                   right_window_sliding_3_padded_dec)
 
right_window_sliding_5_padded_enc = np.concatenate((right_window_in_padded,
                                                    sliding_in_5_padded))
right_window_sliding_5_padded_dec = np.concatenate((right_window_out_padded,
                                                    sliding_out_5_padded))
right_window_sliding_5_dataset = create_tf_dataset(right_window_sliding_5_padded_enc,
                                                   right_window_sliding_5_padded_dec)
 
right_window_sliding_7_padded_enc = np.concatenate((right_window_in_padded, 
                                                    sliding_in_7_padded))
right_window_sliding_7_padded_dec = np.concatenate((right_window_out_padded, 
                                                   sliding_out_7_padded))
right_window_sliding_7_dataset = create_tf_dataset(right_window_sliding_7_padded_enc, 
                                                   right_window_sliding_7_padded_dec)
 
right_window_sliding_9_padded_enc = np.concatenate((right_window_in_padded, 
                                                    sliding_in_9_padded))
right_window_sliding_9_padded_dec = np.concatenate((right_window_out_padded, 
                                                    sliding_out_9_padded))
right_window_sliding_9_dataset = create_tf_dataset(right_window_sliding_9_padded_enc, 
                                                   right_window_sliding_9_padded_dec)
 
right_window_sliding_11_padded_enc = np.concatenate((right_window_in_padded, 
                                                     sliding_in_11_padded))
right_window_sliding_11_padded_dec = np.concatenate((right_window_out_padded, 
                                                     sliding_out_11_padded))
right_window_sliding_11_dataset = create_tf_dataset(right_window_sliding_11_padded_enc, 
                                                    right_window_sliding_11_padded_dec)
 
right_window_sliding_13_padded_enc = np.concatenate((right_window_in_padded, 
                                                     sliding_in_13_padded))
right_window_sliding_13_padded_dec = np.concatenate((right_window_out_padded, 
                                                     sliding_out_13_padded))
right_window_sliding_13_dataset = create_tf_dataset(right_window_sliding_13_padded_enc, 
                                                    right_window_sliding_13_padded_dec)
 
# hybrid datasets sliding 7 + other
sliding_7_left_window_padded_enc = np.concatenate((sliding_in_7_padded,
                                                      left_window_in_padded))
sliding_7_left_window_padded_dec = np.concatenate((sliding_out_7_padded,
                                                      left_window_out_padded))
sliding_7_left_window_dataset = create_tf_dataset(sliding_7_left_window_padded_enc,
                                                     sliding_7_left_window_padded_dec)
 
sliding_7_sliding_3_padded_enc = np.concatenate((sliding_in_7_padded,
                                                    sliding_in_3_padded))
sliding_7_sliding_3_padded_dec = np.concatenate((sliding_out_7_padded,
                                                    sliding_out_3_padded))
sliding_7_sliding_3_dataset = create_tf_dataset(sliding_7_sliding_3_padded_enc,
                                                   sliding_7_sliding_3_padded_dec)
 
sliding_7_sliding_5_padded_enc = np.concatenate((sliding_in_7_padded,
                                                    sliding_in_5_padded))
sliding_7_sliding_5_padded_dec = np.concatenate((sliding_out_7_padded,
                                                    sliding_out_5_padded))
sliding_7_sliding_5_dataset = create_tf_dataset(sliding_7_sliding_5_padded_enc,
                                                   sliding_7_sliding_5_padded_dec)
 
sliding_7_sliding_9_padded_enc = np.concatenate((sliding_in_7_padded, 
                                                    sliding_in_9_padded))
sliding_7_sliding_9_padded_dec = np.concatenate((sliding_out_7_padded, 
                                                    sliding_out_9_padded))
sliding_7_sliding_9_dataset = create_tf_dataset(sliding_7_sliding_9_padded_enc, 
                                                   sliding_7_sliding_9_padded_dec)
 
sliding_7_sliding_11_padded_enc = np.concatenate((sliding_in_7_padded, 
                                                     sliding_in_11_padded))
sliding_7_sliding_11_padded_dec = np.concatenate((sliding_out_7_padded, 
                                                     sliding_out_11_padded))
sliding_7_sliding_11_dataset = create_tf_dataset(sliding_7_sliding_11_padded_enc, 
                                                    sliding_7_sliding_11_padded_dec)
 
sliding_7_sliding_13_padded_enc = np.concatenate((sliding_in_7_padded, 
                                                     sliding_in_13_padded))
sliding_7_sliding_13_padded_dec = np.concatenate((sliding_out_7_padded, 
                                                     sliding_out_13_padded))
sliding_7_sliding_13_dataset = create_tf_dataset(sliding_7_sliding_13_padded_enc, 
                                                    sliding_7_sliding_13_padded_dec)
 
# hybrid datasets sliding 9 + other
sliding_9_left_window_padded_enc = np.concatenate((sliding_in_9_padded,
                                                      left_window_in_padded))
sliding_9_left_window_padded_dec = np.concatenate((sliding_out_9_padded,
                                                      left_window_out_padded))
sliding_9_left_window_dataset = create_tf_dataset(sliding_9_left_window_padded_enc,
                                                     sliding_9_left_window_padded_dec)
 
sliding_9_sliding_3_padded_enc = np.concatenate((sliding_in_9_padded,
                                                    sliding_in_3_padded))
sliding_9_sliding_3_padded_dec = np.concatenate((sliding_out_9_padded,
                                                    sliding_out_3_padded))
sliding_9_sliding_3_dataset = create_tf_dataset(sliding_9_sliding_3_padded_enc,
                                                   sliding_9_sliding_3_padded_dec)
 
sliding_9_sliding_5_padded_enc = np.concatenate((sliding_in_9_padded,
                                                    sliding_in_5_padded))
sliding_9_sliding_5_padded_dec = np.concatenate((sliding_out_9_padded,
                                                    sliding_out_5_padded))
sliding_9_sliding_5_dataset = create_tf_dataset(sliding_9_sliding_5_padded_enc,
                                                   sliding_9_sliding_5_padded_dec)
 
sliding_9_sliding_7_padded_enc = np.concatenate((sliding_in_9_padded, 
                                                    sliding_in_7_padded))
sliding_9_sliding_7_padded_dec = np.concatenate((sliding_out_9_padded, 
                                                    sliding_out_7_padded))
sliding_9_sliding_7_dataset = create_tf_dataset(sliding_9_sliding_7_padded_enc, 
                                                   sliding_9_sliding_7_padded_dec)
 
sliding_9_sliding_11_padded_enc = np.concatenate((sliding_in_9_padded, 
                                                     sliding_in_11_padded))
sliding_9_sliding_11_padded_dec = np.concatenate((sliding_out_9_padded, 
                                                     sliding_out_11_padded))
sliding_9_sliding_11_dataset = create_tf_dataset(sliding_9_sliding_11_padded_enc, 
                                                    sliding_9_sliding_11_padded_dec)
 
sliding_9_sliding_13_padded_enc = np.concatenate((sliding_in_9_padded, 
                                                     sliding_in_13_padded))
sliding_9_sliding_13_padded_dec = np.concatenate((sliding_out_9_padded, 
                                                     sliding_out_13_padded))
sliding_9_sliding_13_dataset = create_tf_dataset(sliding_9_sliding_13_padded_enc, 
                                                    sliding_9_sliding_13_padded_dec)

# hybrid datasets sliding 11 + other
sliding_11_left_window_padded_enc = np.concatenate((sliding_in_11_padded,
                                                      left_window_in_padded))
sliding_11_left_window_padded_dec = np.concatenate((sliding_out_11_padded,
                                                      left_window_out_padded))
sliding_11_left_window_dataset = create_tf_dataset(sliding_11_left_window_padded_enc,
                                                     sliding_11_left_window_padded_dec)
 
sliding_11_sliding_3_padded_enc = np.concatenate((sliding_in_11_padded,
                                                    sliding_in_3_padded))
sliding_11_sliding_3_padded_dec = np.concatenate((sliding_out_11_padded,
                                                    sliding_out_3_padded))
sliding_11_sliding_3_dataset = create_tf_dataset(sliding_11_sliding_3_padded_enc,
                                                   sliding_11_sliding_3_padded_dec)
 
sliding_11_sliding_5_padded_enc = np.concatenate((sliding_in_11_padded,
                                                    sliding_in_5_padded))
sliding_11_sliding_5_padded_dec = np.concatenate((sliding_out_11_padded,
                                                    sliding_out_5_padded))
sliding_11_sliding_5_dataset = create_tf_dataset(sliding_11_sliding_5_padded_enc,
                                                   sliding_11_sliding_5_padded_dec)
 
sliding_11_sliding_7_padded_enc = np.concatenate((sliding_in_11_padded, 
                                                    sliding_in_7_padded))
sliding_11_sliding_7_padded_dec = np.concatenate((sliding_out_11_padded, 
                                                    sliding_out_7_padded))
sliding_11_sliding_7_dataset = create_tf_dataset(sliding_11_sliding_7_padded_enc, 
                                                   sliding_11_sliding_7_padded_dec)
 
sliding_11_sliding_9_padded_enc = np.concatenate((sliding_in_11_padded, 
                                                    sliding_in_9_padded))
sliding_11_sliding_9_padded_dec = np.concatenate((sliding_out_11_padded, 
                                                    sliding_out_9_padded))
sliding_11_sliding_9_dataset = create_tf_dataset(sliding_11_sliding_9_padded_enc, 
                                                   sliding_11_sliding_9_padded_dec)
 
sliding_11_sliding_13_padded_enc = np.concatenate((sliding_in_11_padded, 
                                                     sliding_in_13_padded))
sliding_11_sliding_13_padded_dec = np.concatenate((sliding_out_11_padded, 
                                                     sliding_out_13_padded))
sliding_11_sliding_13_dataset = create_tf_dataset(sliding_11_sliding_13_padded_enc, 
                                                    sliding_11_sliding_13_padded_dec)
 
# right window + sliding 7 + other
right_sliding_7_left_window_padded_enc = np.concatenate((right_window_in_padded,
                                                         sliding_in_7_padded,
                                                         left_window_in_padded))
right_sliding_7_left_window_padded_dec = np.concatenate((right_window_out_padded,
                                                        sliding_out_7_padded,
                                                        left_window_out_padded))
right_sliding_7_left_window_dataset = create_tf_dataset(right_sliding_7_left_window_padded_enc,
                                                     right_sliding_7_left_window_padded_dec)
 
right_sliding_7_sliding_3_padded_enc = np.concatenate((right_window_in_padded,
                                                       sliding_in_7_padded,
                                                       sliding_in_3_padded))
right_sliding_7_sliding_3_padded_dec = np.concatenate((right_window_out_padded,
                                                       sliding_out_7_padded,
                                                       sliding_out_3_padded))
right_sliding_7_sliding_3_dataset = create_tf_dataset(right_sliding_7_sliding_3_padded_enc,
                                                   right_sliding_7_sliding_3_padded_dec)
 
right_sliding_7_sliding_5_padded_enc = np.concatenate((right_window_in_padded,
                                                       sliding_in_7_padded,
                                                       sliding_in_5_padded))
right_sliding_7_sliding_5_padded_dec = np.concatenate((right_window_out_padded,
                                                       sliding_out_7_padded,
                                                       sliding_out_5_padded))
right_sliding_7_sliding_5_dataset = create_tf_dataset(right_sliding_7_sliding_5_padded_enc,
                                                   right_sliding_7_sliding_5_padded_dec)
 
right_sliding_7_sliding_9_padded_enc = np.concatenate((right_window_in_padded,
                                                       sliding_in_7_padded, 
                                                       sliding_in_9_padded))
right_sliding_7_sliding_9_padded_dec = np.concatenate((right_window_out_padded,
                                                       sliding_out_7_padded, 
                                                       sliding_out_9_padded))
right_sliding_7_sliding_9_dataset = create_tf_dataset(right_sliding_7_sliding_9_padded_enc, 
                                                   right_sliding_7_sliding_9_padded_dec)
 
right_sliding_7_sliding_11_padded_enc = np.concatenate((right_window_in_padded,
                                                        sliding_in_7_padded, 
                                                        sliding_in_11_padded))
right_sliding_7_sliding_11_padded_dec = np.concatenate((right_window_out_padded,
                                                        sliding_out_7_padded, 
                                                        sliding_out_11_padded))
right_sliding_7_sliding_11_dataset = create_tf_dataset(right_sliding_7_sliding_11_padded_enc, 
                                                    right_sliding_7_sliding_11_padded_dec)
 
right_sliding_7_sliding_13_padded_enc = np.concatenate((right_window_in_padded,
                                                        sliding_in_7_padded, 
                                                        sliding_in_13_padded))
right_sliding_7_sliding_13_padded_dec = np.concatenate((right_window_out_padded,
                                                        sliding_out_7_padded, 
                                                        sliding_out_13_padded))
right_sliding_7_sliding_13_dataset = create_tf_dataset(right_sliding_7_sliding_13_padded_enc, 
                                                    right_sliding_7_sliding_13_padded_dec)
 
# right window + sliding 13 + other
right_sliding_13_left_window_padded_enc = np.concatenate((right_window_in_padded,
                                                         sliding_in_13_padded,
                                                         left_window_in_padded))
right_sliding_13_left_window_padded_dec = np.concatenate((right_window_out_padded,
                                                        sliding_out_13_padded,
                                                        left_window_out_padded))
right_sliding_13_left_window_dataset = create_tf_dataset(right_sliding_13_left_window_padded_enc,
                                                     right_sliding_13_left_window_padded_dec)
 
right_sliding_13_sliding_3_padded_enc = np.concatenate((right_window_in_padded,
                                                       sliding_in_13_padded,
                                                       sliding_in_3_padded))
right_sliding_13_sliding_3_padded_dec = np.concatenate((right_window_out_padded,
                                                       sliding_out_13_padded,
                                                       sliding_out_3_padded))
right_sliding_13_sliding_3_dataset = create_tf_dataset(right_sliding_13_sliding_3_padded_enc,
                                                   right_sliding_13_sliding_3_padded_dec)
 
right_sliding_13_sliding_5_padded_enc = np.concatenate((right_window_in_padded,
                                                       sliding_in_13_padded,
                                                       sliding_in_5_padded))
right_sliding_13_sliding_5_padded_dec = np.concatenate((right_window_out_padded,
                                                       sliding_out_13_padded,
                                                       sliding_out_5_padded))
right_sliding_13_sliding_5_dataset = create_tf_dataset(right_sliding_13_sliding_5_padded_enc,
                                                   right_sliding_13_sliding_5_padded_dec)
 
right_sliding_13_sliding_9_padded_enc = np.concatenate((right_window_in_padded,
                                                       sliding_in_13_padded, 
                                                       sliding_in_9_padded))
right_sliding_13_sliding_9_padded_dec = np.concatenate((right_window_out_padded,
                                                       sliding_out_13_padded, 
                                                       sliding_out_9_padded))
right_sliding_13_sliding_9_dataset = create_tf_dataset(right_sliding_13_sliding_9_padded_enc, 
                                                   right_sliding_13_sliding_9_padded_dec)
 
right_sliding_13_sliding_11_padded_enc = np.concatenate((right_window_in_padded,
                                                        sliding_in_13_padded, 
                                                        sliding_in_11_padded))
right_sliding_13_sliding_11_padded_dec = np.concatenate((right_window_out_padded,
                                                        sliding_out_13_padded, 
                                                        sliding_out_11_padded))
right_sliding_13_sliding_11_dataset = create_tf_dataset(right_sliding_13_sliding_11_padded_enc, 
                                                    right_sliding_13_sliding_11_padded_dec)
 
right_sliding_13_sliding_7_padded_enc = np.concatenate((right_window_in_padded,
                                                        sliding_in_13_padded, 
                                                        sliding_in_7_padded))
right_sliding_13_sliding_7_padded_dec = np.concatenate((right_window_out_padded,
                                                        sliding_out_13_padded, 
                                                        sliding_out_7_padded))
right_sliding_13_sliding_7_dataset = create_tf_dataset(right_sliding_13_sliding_7_padded_enc, 
                                                    right_sliding_13_sliding_7_padded_dec)

# right window + sliding 7 window + left window + other
right_sliding_7_left_window_sliding_3_padded_enc = np.concatenate((right_window_in_padded,
                                                         sliding_in_7_padded,
                                                         left_window_in_padded,
                                                         sliding_in_3_padded))
right_sliding_7_left_window_sliding_3_padded_dec = np.concatenate((right_window_out_padded,
                                                        sliding_out_7_padded,
                                                        left_window_out_padded,
                                                         sliding_out_3_padded))
right_sliding_7_left_window_sliding_3_dataset = create_tf_dataset(right_sliding_7_left_window_sliding_3_padded_enc,
                                                     right_sliding_7_left_window_sliding_3_padded_dec)
 
right_sliding_7_left_window_sliding_5_padded_enc = np.concatenate((right_window_in_padded,
                                                         sliding_in_7_padded,
                                                         left_window_in_padded,
                                                         sliding_in_5_padded))
right_sliding_7_left_window_sliding_5_padded_dec = np.concatenate((right_window_out_padded,
                                                        sliding_out_7_padded,
                                                        left_window_out_padded,
                                                        sliding_out_5_padded))
right_sliding_7_left_window_sliding_5_dataset = create_tf_dataset(right_sliding_7_left_window_sliding_5_padded_enc,
                                                     right_sliding_7_left_window_sliding_5_padded_dec)
 
right_sliding_7_left_window_sliding_9_padded_enc = np.concatenate((right_window_in_padded,
                                                         sliding_in_7_padded,
                                                         left_window_in_padded,
                                                         sliding_in_9_padded))
right_sliding_7_left_window_sliding_9_padded_dec = np.concatenate((right_window_out_padded,
                                                        sliding_out_7_padded,
                                                        left_window_out_padded,
                                                        sliding_out_9_padded))
right_sliding_7_left_window_sliding_9_dataset = create_tf_dataset(right_sliding_7_left_window_sliding_9_padded_enc,
                                                     right_sliding_7_left_window_sliding_9_padded_dec)
 
right_sliding_7_left_window_sliding_11_padded_enc = np.concatenate((right_window_in_padded,
                                                         sliding_in_7_padded,
                                                         left_window_in_padded,
                                                         sliding_in_11_padded))
right_sliding_7_left_window_sliding_11_padded_dec = np.concatenate((right_window_out_padded,
                                                        sliding_out_7_padded,
                                                        left_window_out_padded,
                                                        sliding_out_11_padded))
right_sliding_7_left_window_sliding_11_dataset = create_tf_dataset(right_sliding_7_left_window_sliding_11_padded_enc,
                                                     right_sliding_7_left_window_sliding_11_padded_dec)
 
right_sliding_7_left_window_sliding_13_padded_enc = np.concatenate((right_window_in_padded,
                                                         sliding_in_7_padded,
                                                         left_window_in_padded,
                                                         sliding_in_13_padded))
right_sliding_7_left_window_sliding_13_padded_dec = np.concatenate((right_window_out_padded,
                                                        sliding_out_7_padded,
                                                        left_window_out_padded,
                                                        sliding_out_13_padded))
right_sliding_7_left_window_sliding_13_dataset = create_tf_dataset(right_sliding_7_left_window_sliding_13_padded_enc,
                                                     right_sliding_7_left_window_sliding_13_padded_dec)
 
# test dataset
enc_test_numpy = np.asarray(test_in_padded, dtype=np.int64)
enc_test_dataset = tf.data.Dataset.from_tensor_slices(enc_test_numpy)
 
dec_test_numpy = np.asarray(test_out_padded, dtype=np.int64)
dec_test_dataset = tf.data.Dataset.from_tensor_slices(dec_test_numpy)
 
test_dataset = tf.data.Dataset.zip((enc_test_dataset, dec_test_dataset))

# %%
# the following set of cells contains the definitions for the Transformer architecture
# the code in this section is from https://www.tensorflow.org/tutorials/text/transformer
def get_angles(pos, i, d_model):
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

# %%
def positional_encoding(position, d_model):
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)
  
  # apply sin to even indices in the array; 2i
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
  
  # apply cos to odd indices in the array; 2i+1
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
    
  pos_encoding = angle_rads[np.newaxis, ...]
    
  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
# create masks
def create_padding_mask(seq):
  seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
  
  # add extra dimensions to add the padding
  # to the attention logits.
  return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

# %%
def create_look_ahead_mask(size):
  mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
  return mask  # (seq_len, seq_len)

# %%
# build machinery for transformer
def scaled_dot_product_attention(q, k, v, mask):
  """Calculate the attention weights.
  q, k, v must have matching leading dimensions.
  k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
  The mask has different shapes depending on its type(padding or look ahead) 
  but it must be broadcastable for addition.
  
  Args:
    q: query shape == (..., seq_len_q, depth)
    k: key shape == (..., seq_len_k, depth)
    v: value shape == (..., seq_len_v, depth_v)
    mask: Float tensor with shape broadcastable 
          to (..., seq_len_q, seq_len_k). Defaults to None.
    
  Returns:
    output, attention_weights
  """
  #print('k:', k.shape)
  #print('q:', q.shape)
  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)
  
  # scale matmul_qk
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)
 
  # add the mask to the scaled tensor.
  if mask is not None:
    scaled_attention_logits += (mask * -1e9)  
 
  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)
 
  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)
 
  return output, attention_weights

# %%
class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads):
    super(MultiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model
    
    assert d_model % self.num_heads == 0
    
    self.depth = d_model // self.num_heads
    
    self.wq = tf.keras.layers.Dense(d_model)
    self.wk = tf.keras.layers.Dense(d_model)
    self.wv = tf.keras.layers.Dense(d_model)
    
    self.dense = tf.keras.layers.Dense(d_model)
        
  def split_heads(self, x, batch_size):
    """Split the last dimension into (num_heads, depth).
    Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
    """
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])
    
  def call(self, v, k, q, mask):
    batch_size = tf.shape(q)[0]
    
    q = self.wq(q)  # (batch_size, seq_len, d_model)
    k = self.wk(k)  # (batch_size, seq_len, d_model)
    v = self.wv(v)  # (batch_size, seq_len, d_model)
    
    q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
    k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
    v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)
    
    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(
        q, k, v, mask)
    
    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)
 
    concat_attention = tf.reshape(scaled_attention, 
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)
 
    output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)
        
    return output, attention_weights

# %%
def point_wise_feed_forward_network(d_model, dff):
  return tf.keras.Sequential([
      tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
      tf.keras.layers.Dense(d_model)  # (batch_size, seq_len, d_model)
  ])

# %%
class EncoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(EncoderLayer, self).__init__()
 
    self.mha = MultiHeadAttention(d_model, num_heads)
    self.ffn = point_wise_feed_forward_network(d_model, dff)
 
    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    
    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    
  def call(self, x, training, mask):
 
    attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
    attn_output = self.dropout1(attn_output, training=training)
    out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)
    
    ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
    ffn_output = self.dropout2(ffn_output, training=training)
    out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)
    
    return out2

# %%
class DecoderLayer(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads, dff, rate=0.1):
    super(DecoderLayer, self).__init__()
 
    self.mha1 = MultiHeadAttention(d_model, num_heads)
    self.mha2 = MultiHeadAttention(d_model, num_heads)
 
    self.ffn = point_wise_feed_forward_network(d_model, dff)
 
    self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
    
    self.dropout1 = tf.keras.layers.Dropout(rate)
    self.dropout2 = tf.keras.layers.Dropout(rate)
    self.dropout3 = tf.keras.layers.Dropout(rate)
    
    
  def call(self, x, enc_output, training, 
           look_ahead_mask, padding_mask):
    # enc_output.shape == (batch_size, input_seq_len, d_model)
 
    attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
    attn1 = self.dropout1(attn1, training=training)
    out1 = self.layernorm1(attn1 + x)
    
    attn2, attn_weights_block2 = self.mha2(
        enc_output, enc_output, out1, padding_mask)  # (batch_size, target_seq_len, d_model)
    attn2 = self.dropout2(attn2, training=training)
    out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)
    
    ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
    ffn_output = self.dropout3(ffn_output, training=training)
    out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)
    
    return out3, attn_weights_block1, attn_weights_block2

# %%
class Encoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Encoder, self).__init__()
 
    self.d_model = d_model
    self.num_layers = num_layers
    
    self.embedding = tf.keras.layers.Embedding(input_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, 
                                            self.d_model)
    
    
    self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) 
                       for _ in range(num_layers)]
  
    self.dropout = tf.keras.layers.Dropout(rate)
        
  def call(self, x, training, mask):
 
    seq_len = tf.shape(x)[1]
    
    # adding embedding and position encoding.
    x = self.embedding(x)  # (batch_size, input_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]
 
    x = self.dropout(x, training=training)
    
    for i in range(self.num_layers):
      x = self.enc_layers[i](x, training, mask)
    
    return x  # (batch_size, input_seq_len, d_model)

# %%
class Decoder(tf.keras.layers.Layer):
  def __init__(self, num_layers, d_model, num_heads, dff, target_vocab_size,
               maximum_position_encoding, rate=0.1):
    super(Decoder, self).__init__()
 
    self.d_model = d_model
    self.num_layers = num_layers
    
    self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
    self.pos_encoding = positional_encoding(maximum_position_encoding, d_model)
    
    self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate) 
                       for _ in range(num_layers)]
    self.dropout = tf.keras.layers.Dropout(rate)
    
  def call(self, x, enc_output, training, 
           look_ahead_mask, padding_mask):
 
    seq_len = tf.shape(x)[1]
    attention_weights = {}
    
    x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
    x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
    x += self.pos_encoding[:, :seq_len, :]
    
    x = self.dropout(x, training=training)
 
    for i in range(self.num_layers):
      x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                             look_ahead_mask, padding_mask)
      
      attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
      attention_weights['decoder_layer{}_block2'.format(i+1)] = block2
    
    # x.shape == (batch_size, target_seq_len, d_model)
    return x, attention_weights

# %%
class Transformer(tf.keras.Model):
  def __init__(self, num_layers, d_model, num_heads, dff, input_vocab_size, 
               target_vocab_size, pe_input, pe_target, rate=0.1):
    super(Transformer, self).__init__()
 
    self.encoder = Encoder(num_layers, d_model, num_heads, dff, 
                           input_vocab_size, pe_input, rate)
 
    self.decoder = Decoder(num_layers, d_model, num_heads, dff, 
                           target_vocab_size, pe_target, rate)
 
    self.final_layer = tf.keras.layers.Dense(target_vocab_size)
    
  def call(self, inp, tar, training, enc_padding_mask, 
           look_ahead_mask, dec_padding_mask):
 
    enc_output = self.encoder(inp, training, enc_padding_mask)  # (batch_size, inp_seq_len, d_model)
    
    # dec_output.shape == (batch_size, tar_seq_len, d_model)
    dec_output, attention_weights = self.decoder(
        tar, enc_output, training, look_ahead_mask, dec_padding_mask)
    
    final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)
    
    return final_output, attention_weights

# %%
num_layers = 1
d_model = 128
dff = 512
num_heads = 8
 
input_vocab_size = len(total_vocab)
target_vocab_size = len(total_vocab)
dropout_rate = 0.1

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
  def __init__(self, d_model, warmup_steps=4000):
    super(CustomSchedule, self).__init__()
    
    self.d_model = d_model
    self.d_model = tf.cast(self.d_model, tf.float32)
 
    self.warmup_steps = warmup_steps
    
  def __call__(self, step):
    arg1 = tf.math.rsqrt(step)
    arg2 = step * (self.warmup_steps ** -1.5)
    
    return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)
 
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98, 
                                     epsilon=1e-9)

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(
    from_logits=True, reduction='none')

# %%
# loss and accuracy functions -- note handling of masks
def loss_function(real, pred):
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  loss_ = loss_object(real, pred)
 
  mask = tf.cast(mask, dtype=loss_.dtype)
  loss_ *= mask
  
  return tf.reduce_sum(loss_)/tf.reduce_sum(mask)
 
 
def accuracy_function(real, pred):
  accuracies = tf.equal(real, tf.argmax(pred, axis=2))
  
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  accuracies = tf.math.logical_and(mask, accuracies)
 
  accuracies = tf.cast(accuracies, dtype=tf.float32)
  mask = tf.cast(mask, dtype=tf.float32)
  return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

# %%
transformer = Transformer(num_layers, d_model, num_heads, dff,
                          input_vocab_size, target_vocab_size, 
                          pe_input=input_vocab_size, 
                          pe_target=target_vocab_size,
                          rate=dropout_rate)

# %%
def create_masks(inp, tar):
  # Encoder padding mask
  enc_padding_mask = create_padding_mask(inp)
  
  # Used in the 2nd attention block in the decoder.
  # This padding mask is used to mask the encoder outputs.
  dec_padding_mask = create_padding_mask(inp)
  
  # Used in the 1st attention block in the decoder.
  # It is used to pad and mask future tokens in the input received by 
  # the decoder.
  look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
  dec_target_padding_mask = create_padding_mask(tar)
  combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)
  
  return enc_padding_mask, combined_mask, dec_padding_mask

# %%
# define checkpoint with example checkpoint path
gdrive_checkpoints = "/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/"
checkpoint_path = gdrive_checkpoints + "right_sliding_13_sliding_11/train"
 
ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)
 
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
# training
EPOCHS = 100

# %%
# original documentation from TensorFlow documentation page:
# The @tf.function trace-compiles train_step into a TF graph for faster
# execution. The function specializes to the precise shape of the argument
# tensors. To avoid re-tracing due to the variable sequence lengths or variable
# batch sizes (the last batch is smaller), use input_signature to specify
# more generic shapes.
 
train_step_signature = [
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
    tf.TensorSpec(shape=(None, None), dtype=tf.int64),
]
 
@tf.function(input_signature=train_step_signature)
def train_step(inp, tar):
  tar_inp = tar[:, :-1]
  tar_real = tar[:, 1:]
  
  enc_padding_mask, combined_mask, dec_padding_mask = create_masks(inp, tar_inp)
  
  with tf.GradientTape() as tape:
    predictions, _ = transformer(inp, tar_inp, 
                                 True, 
                                 enc_padding_mask, 
                                 combined_mask, 
                                 dec_padding_mask)
    loss = loss_function(tar_real, predictions)
 
  gradients = tape.gradient(loss, transformer.trainable_variables)    
  optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))
  
  train_loss(loss)
  train_accuracy(accuracy_function(tar_real, predictions))

# %%
# training for loop
for epoch in range(EPOCHS):
  start = time.time()
  
  train_loss.reset_states()
  train_accuracy.reset_states()
  
  # inp -> chars, tar -> words
  for (batch, (inp, tar)) in enumerate(right_sliding_13_sliding_11_dataset):
    train_step(inp, tar)
    
    if batch % 50 == 0:
      print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
          epoch + 1, batch, train_loss.result(), train_accuracy.result()))
      
  if (epoch + 1) % 5 == 0:
    ckpt_save_path = ckpt_manager.save()
    print ('Saving checkpoint for epoch {} at {}'.format(epoch+1,
                                                         ckpt_save_path))
    
  print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1, 
                                                train_loss.result(), 
                                                train_accuracy.result()))
 
  print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 1 Batch 0 Loss 7.4739 Accuracy 0.0025
# Epoch 1 Batch 50 Loss 7.4016 Accuracy 0.0032
# Epoch 1 Batch 100 Loss 7.2634 Accuracy 0.0512
# Epoch 1 Batch 150 Loss 7.1090 Accuracy 0.0646
# Epoch 1 Batch 200 Loss 6.9102 Accuracy 0.0749
# Epoch 1 Batch 250 Loss 6.7520 Accuracy 0.0762
# Epoch 1 Batch 300 Loss 6.5506 Accuracy 0.0858
# Epoch 1 Batch 350 Loss 6.3532 Accuracy 0.0935
# Epoch 1 Loss 6.2491 Accuracy 0.0964
# Time taken for 1 epoch: 25.94491147994995 secs
#
# Epoch 2 Batch 0 Loss 5.2122 Accuracy 0.0810
# Epoch 2 Batch 50 Loss 4.5409 Accuracy 0.2020
# Epoch 2 Batch 100 Loss 4.5246 Accuracy 0.2049
# Epoch 2 Batch 150 Loss 4.6094 Accuracy 0.1907
# Epoch 2 Batch 200 Loss 4.5845 Accuracy 0.1889
# Epoch 2 Batch 250 Loss 4.6138 Accuracy 0.1832
# Epoch 2 Batch 300 Loss 4.5981 Accuracy 0.1874
# Epoch 2 Batch 350 Loss 4.5599 Accuracy 0.1934
# Epoch 2 Loss 4.5529 Accuracy 0.1950
# Time taken for 1 epoch: 22.832216501235962 secs
#
# Epoch 3 Batch 0 Loss 4.9523 Accuracy 0.1975
# Epoch 3 Batch 50 Loss 3.8810 Accuracy 0.3359
# Epoch 3 Batch 100 Loss 3.9236 Accuracy 0.3251
# Epoch 3 Batch 150 Loss 4.0733 Accuracy 0.3014
# Epoch 3 Batch 200 Loss 4.0648 Accuracy 0.2958
# Epoch 3 Batch 250 Loss 4.1017 Accuracy 0.2852
# Epoch 3 Batch 300 Loss 4.0790 Accuracy 0.2866
# Epoch 3 Batch 350 Loss 4.0333 Accuracy 0.2911
# Epoch 3 Loss 4.0205 Accuracy 0.2914
# Time taken for 1 epoch: 22.833375692367554 secs
#
# Epoch 4 Batch 0 Loss 4.4068 Accuracy 0.2127
# Epoch 4 Batch 50 Loss 3.2288 Accuracy 0.4144
# Epoch 4 Batch 100 Loss 3.2946 Accuracy 0.3958
# Epoch 4 Batch 150 Loss 3.4120 Accuracy 0.3775
# Epoch 4 Batch 200 Loss 3.3905 Accuracy 0.3746
# Epoch 4 Batch 250 Loss 3.4144 Accuracy 0.3665
# Epoch 4 Batch 300 Loss 3.3745 Accuracy 0.3702
# Epoch 4 Batch 350 Loss 3.3170 Accuracy 0.3762
# Epoch 4 Loss 3.2895 Accuracy 0.3791
# Time taken for 1 epoch: 23.091802835464478 secs
#
# Epoch 5 Batch 0 Loss 3.5719 Accuracy 0.3241
# Epoch 5 Batch 50 Loss 2.4765 Accuracy 0.5133
# Epoch 5 Batch 100 Loss 2.5230 Accuracy 0.4974
# Epoch 5 Batch 150 Loss 2.6379 Accuracy 0.4757
# Epoch 5 Batch 200 Loss 2.6127 Accuracy 0.4738
# Epoch 5 Batch 250 Loss 2.6173 Accuracy 0.4698
# Epoch 5 Batch 300 Loss 2.5821 Accuracy 0.4742
# Epoch 5 Batch 350 Loss 2.5166 Accuracy 0.4837
# Saving checkpoint for epoch 5 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-1
# Epoch 5 Loss 2.4775 Accuracy 0.4900
# Time taken for 1 epoch: 23.417924404144287 secs
#
# Epoch 6 Batch 0 Loss 2.8266 Accuracy 0.4127
# Epoch 6 Batch 50 Loss 1.8615 Accuracy 0.6081
# Epoch 6 Batch 100 Loss 1.8660 Accuracy 0.5983
# Epoch 6 Batch 150 Loss 1.9719 Accuracy 0.5762
# Epoch 6 Batch 200 Loss 1.9422 Accuracy 0.5762
# Epoch 6 Batch 250 Loss 1.9214 Accuracy 0.5782
# Epoch 6 Batch 300 Loss 1.8920 Accuracy 0.5821
# Epoch 6 Batch 350 Loss 1.8304 Accuracy 0.5933
# Epoch 6 Loss 1.7897 Accuracy 0.6016
# Time taken for 1 epoch: 22.692758798599243 secs
#
# Epoch 7 Batch 0 Loss 1.9925 Accuracy 0.5646
# Epoch 7 Batch 50 Loss 1.3436 Accuracy 0.6984
# Epoch 7 Batch 100 Loss 1.3447 Accuracy 0.6927
# Epoch 7 Batch 150 Loss 1.4470 Accuracy 0.6704
# Epoch 7 Batch 200 Loss 1.4208 Accuracy 0.6717
# Epoch 7 Batch 250 Loss 1.3900 Accuracy 0.6772
# Epoch 7 Batch 300 Loss 1.3713 Accuracy 0.6797
# Epoch 7 Batch 350 Loss 1.3194 Accuracy 0.6906
# Epoch 7 Loss 1.2817 Accuracy 0.6993
# Time taken for 1 epoch: 22.65435004234314 secs
#
# Epoch 8 Batch 0 Loss 1.4641 Accuracy 0.6911
# Epoch 8 Batch 50 Loss 1.0182 Accuracy 0.7627
# Epoch 8 Batch 100 Loss 0.9971 Accuracy 0.7645
# Epoch 8 Batch 150 Loss 1.0822 Accuracy 0.7444
# Epoch 8 Batch 200 Loss 1.0651 Accuracy 0.7447
# Epoch 8 Batch 250 Loss 1.0260 Accuracy 0.7529
# Epoch 8 Batch 300 Loss 1.0100 Accuracy 0.7557
# Epoch 8 Batch 350 Loss 0.9681 Accuracy 0.7649
# Epoch 8 Loss 0.9363 Accuracy 0.7725
# Time taken for 1 epoch: 22.768882513046265 secs
#
# Epoch 9 Batch 0 Loss 1.0103 Accuracy 0.7595
# Epoch 9 Batch 50 Loss 0.8013 Accuracy 0.8057
# Epoch 9 Batch 100 Loss 0.7749 Accuracy 0.8099
# Epoch 9 Batch 150 Loss 0.8246 Accuracy 0.7967
# Epoch 9 Batch 200 Loss 0.8068 Accuracy 0.7980
# Epoch 9 Batch 250 Loss 0.7661 Accuracy 0.8074
# Epoch 9 Batch 300 Loss 0.7455 Accuracy 0.8121
# Epoch 9 Batch 350 Loss 0.7095 Accuracy 0.8208
# Epoch 9 Loss 0.6834 Accuracy 0.8273
# Time taken for 1 epoch: 22.83286166191101 secs
#
# Epoch 10 Batch 0 Loss 0.7702 Accuracy 0.8152
# Epoch 10 Batch 50 Loss 0.6064 Accuracy 0.8492
# Epoch 10 Batch 100 Loss 0.6020 Accuracy 0.8468
# Epoch 10 Batch 150 Loss 0.6375 Accuracy 0.8372
# Epoch 10 Batch 200 Loss 0.6136 Accuracy 0.8414
# Epoch 10 Batch 250 Loss 0.5797 Accuracy 0.8498
# Epoch 10 Batch 300 Loss 0.5642 Accuracy 0.8535
# Epoch 10 Batch 350 Loss 0.5351 Accuracy 0.8609
# Saving checkpoint for epoch 10 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-2
# Epoch 10 Loss 0.5123 Accuracy 0.8669
# Time taken for 1 epoch: 22.955759286880493 secs
#
# Epoch 11 Batch 0 Loss 0.4480 Accuracy 0.8785
# Epoch 11 Batch 50 Loss 0.4532 Accuracy 0.8834
# Epoch 11 Batch 100 Loss 0.4719 Accuracy 0.8765
# Epoch 11 Batch 150 Loss 0.5036 Accuracy 0.8678
# Epoch 11 Batch 200 Loss 0.4794 Accuracy 0.8730
# Epoch 11 Batch 250 Loss 0.4486 Accuracy 0.8811
# Epoch 11 Batch 300 Loss 0.4291 Accuracy 0.8859
# Epoch 11 Batch 350 Loss 0.4036 Accuracy 0.8928
# Epoch 11 Loss 0.3847 Accuracy 0.8978
# Time taken for 1 epoch: 22.760972261428833 secs
#
# Epoch 12 Batch 0 Loss 0.3113 Accuracy 0.9215
# Epoch 12 Batch 50 Loss 0.3726 Accuracy 0.9048
# Epoch 12 Batch 100 Loss 0.3751 Accuracy 0.9016
# Epoch 12 Batch 150 Loss 0.3950 Accuracy 0.8957
# Epoch 12 Batch 200 Loss 0.3728 Accuracy 0.9000
# Epoch 12 Batch 250 Loss 0.3450 Accuracy 0.9073
# Epoch 12 Batch 300 Loss 0.3280 Accuracy 0.9118
# Epoch 12 Batch 350 Loss 0.3073 Accuracy 0.9174
# Epoch 12 Loss 0.2916 Accuracy 0.9217
# Time taken for 1 epoch: 22.691782474517822 secs
#
# Epoch 13 Batch 0 Loss 0.2101 Accuracy 0.9316
# Epoch 13 Batch 50 Loss 0.2767 Accuracy 0.9282
# Epoch 13 Batch 100 Loss 0.2959 Accuracy 0.9215
# Epoch 13 Batch 150 Loss 0.3090 Accuracy 0.9173
# Epoch 13 Batch 200 Loss 0.2937 Accuracy 0.9208
# Epoch 13 Batch 250 Loss 0.2725 Accuracy 0.9266
# Epoch 13 Batch 300 Loss 0.2571 Accuracy 0.9307
# Epoch 13 Batch 350 Loss 0.2415 Accuracy 0.9350
# Epoch 13 Loss 0.2306 Accuracy 0.9379
# Time taken for 1 epoch: 23.17919397354126 secs
#
# Epoch 14 Batch 0 Loss 0.1682 Accuracy 0.9519
# Epoch 14 Batch 50 Loss 0.2289 Accuracy 0.9394
# Epoch 14 Batch 100 Loss 0.2245 Accuracy 0.9397
# Epoch 14 Batch 150 Loss 0.2282 Accuracy 0.9380
# Epoch 14 Batch 200 Loss 0.2177 Accuracy 0.9406
# Epoch 14 Batch 250 Loss 0.2000 Accuracy 0.9456
# Epoch 14 Batch 300 Loss 0.1916 Accuracy 0.9478
# Epoch 14 Batch 350 Loss 0.1813 Accuracy 0.9506
# Epoch 14 Loss 0.1722 Accuracy 0.9531
# Time taken for 1 epoch: 22.946956872940063 secs
#
# Epoch 15 Batch 0 Loss 0.1047 Accuracy 0.9696
# Epoch 15 Batch 50 Loss 0.1805 Accuracy 0.9523
# Epoch 15 Batch 100 Loss 0.1775 Accuracy 0.9513
# Epoch 15 Batch 150 Loss 0.1809 Accuracy 0.9503
# Epoch 15 Batch 200 Loss 0.1711 Accuracy 0.9526
# Epoch 15 Batch 250 Loss 0.1584 Accuracy 0.9563
# Epoch 15 Batch 300 Loss 0.1513 Accuracy 0.9583
# Epoch 15 Batch 350 Loss 0.1435 Accuracy 0.9605
# Saving checkpoint for epoch 15 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-3
# Epoch 15 Loss 0.1372 Accuracy 0.9623
# Time taken for 1 epoch: 22.9663188457489 secs
#
# Epoch 16 Batch 0 Loss 0.1822 Accuracy 0.9494
# Epoch 16 Batch 50 Loss 0.1639 Accuracy 0.9554
# Epoch 16 Batch 100 Loss 0.1592 Accuracy 0.9566
# Epoch 16 Batch 150 Loss 0.1591 Accuracy 0.9561
# Epoch 16 Batch 200 Loss 0.1490 Accuracy 0.9585
# Epoch 16 Batch 250 Loss 0.1364 Accuracy 0.9622
# Epoch 16 Batch 300 Loss 0.1303 Accuracy 0.9639
# Epoch 16 Batch 350 Loss 0.1246 Accuracy 0.9655
# Epoch 16 Loss 0.1186 Accuracy 0.9672
# Time taken for 1 epoch: 22.77525758743286 secs
#
# Epoch 17 Batch 0 Loss 0.0842 Accuracy 0.9797
# Epoch 17 Batch 50 Loss 0.1354 Accuracy 0.9635
# Epoch 17 Batch 100 Loss 0.1327 Accuracy 0.9638
# Epoch 17 Batch 150 Loss 0.1337 Accuracy 0.9631
# Epoch 17 Batch 200 Loss 0.1246 Accuracy 0.9654
# Epoch 17 Batch 250 Loss 0.1137 Accuracy 0.9686
# Epoch 17 Batch 300 Loss 0.1090 Accuracy 0.9697
# Epoch 17 Batch 350 Loss 0.1043 Accuracy 0.9710
# Epoch 17 Loss 0.1001 Accuracy 0.9722
# Time taken for 1 epoch: 22.857869625091553 secs
#
# Epoch 18 Batch 0 Loss 0.0877 Accuracy 0.9823
# Epoch 18 Batch 50 Loss 0.1216 Accuracy 0.9667
# Epoch 18 Batch 100 Loss 0.1210 Accuracy 0.9673
# Epoch 18 Batch 150 Loss 0.1210 Accuracy 0.9667
# Epoch 18 Batch 200 Loss 0.1123 Accuracy 0.9691
# Epoch 18 Batch 250 Loss 0.1028 Accuracy 0.9718
# Epoch 18 Batch 300 Loss 0.0985 Accuracy 0.9730
# Epoch 18 Batch 350 Loss 0.0934 Accuracy 0.9744
# Epoch 18 Loss 0.0897 Accuracy 0.9754
# Time taken for 1 epoch: 22.815377235412598 secs
#
# Epoch 19 Batch 0 Loss 0.0836 Accuracy 0.9722
# Epoch 19 Batch 50 Loss 0.0914 Accuracy 0.9747
# Epoch 19 Batch 100 Loss 0.0965 Accuracy 0.9730
# Epoch 19 Batch 150 Loss 0.1018 Accuracy 0.9715
# Epoch 19 Batch 200 Loss 0.0949 Accuracy 0.9732
# Epoch 19 Batch 250 Loss 0.0870 Accuracy 0.9754
# Epoch 19 Batch 300 Loss 0.0823 Accuracy 0.9768
# Epoch 19 Batch 350 Loss 0.0784 Accuracy 0.9781
# Epoch 19 Loss 0.0754 Accuracy 0.9790
# Time taken for 1 epoch: 22.787363529205322 secs
#
# Epoch 20 Batch 0 Loss 0.0495 Accuracy 0.9797
# Epoch 20 Batch 50 Loss 0.0883 Accuracy 0.9759
# Epoch 20 Batch 100 Loss 0.0879 Accuracy 0.9754
# Epoch 20 Batch 150 Loss 0.0942 Accuracy 0.9736
# Epoch 20 Batch 200 Loss 0.0862 Accuracy 0.9756
# Epoch 20 Batch 250 Loss 0.0795 Accuracy 0.9777
# Epoch 20 Batch 300 Loss 0.0762 Accuracy 0.9786
# Epoch 20 Batch 350 Loss 0.0726 Accuracy 0.9798
# Saving checkpoint for epoch 20 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-4
# Epoch 20 Loss 0.0699 Accuracy 0.9806
# Time taken for 1 epoch: 22.90856146812439 secs
#
# Epoch 21 Batch 0 Loss 0.0761 Accuracy 0.9772
# Epoch 21 Batch 50 Loss 0.0795 Accuracy 0.9784
# Epoch 21 Batch 100 Loss 0.0784 Accuracy 0.9784
# Epoch 21 Batch 150 Loss 0.0810 Accuracy 0.9777
# Epoch 21 Batch 200 Loss 0.0763 Accuracy 0.9788
# Epoch 21 Batch 250 Loss 0.0700 Accuracy 0.9807
# Epoch 21 Batch 300 Loss 0.0671 Accuracy 0.9815
# Epoch 21 Batch 350 Loss 0.0644 Accuracy 0.9821
# Epoch 21 Loss 0.0618 Accuracy 0.9828
# Time taken for 1 epoch: 22.90987253189087 secs
#
# Epoch 22 Batch 0 Loss 0.0450 Accuracy 0.9873
# Epoch 22 Batch 50 Loss 0.0682 Accuracy 0.9814
# Epoch 22 Batch 100 Loss 0.0698 Accuracy 0.9810
# Epoch 22 Batch 150 Loss 0.0726 Accuracy 0.9800
# Epoch 22 Batch 200 Loss 0.0687 Accuracy 0.9810
# Epoch 22 Batch 250 Loss 0.0631 Accuracy 0.9827
# Epoch 22 Batch 300 Loss 0.0610 Accuracy 0.9833
# Epoch 22 Batch 350 Loss 0.0588 Accuracy 0.9838
# Epoch 22 Loss 0.0560 Accuracy 0.9845
# Time taken for 1 epoch: 22.960665702819824 secs
#
# Epoch 23 Batch 0 Loss 0.0712 Accuracy 0.9848
# Epoch 23 Batch 50 Loss 0.0649 Accuracy 0.9824
# Epoch 23 Batch 100 Loss 0.0642 Accuracy 0.9825
# Epoch 23 Batch 150 Loss 0.0666 Accuracy 0.9817
# Epoch 23 Batch 200 Loss 0.0623 Accuracy 0.9829
# Epoch 23 Batch 250 Loss 0.0578 Accuracy 0.9840
# Epoch 23 Batch 300 Loss 0.0558 Accuracy 0.9845
# Epoch 23 Batch 350 Loss 0.0537 Accuracy 0.9851
# Epoch 23 Loss 0.0516 Accuracy 0.9857
# Time taken for 1 epoch: 23.1338312625885 secs
#
# Epoch 24 Batch 0 Loss 0.0490 Accuracy 0.9848
# Epoch 24 Batch 50 Loss 0.0609 Accuracy 0.9829
# Epoch 24 Batch 100 Loss 0.0618 Accuracy 0.9826
# Epoch 24 Batch 150 Loss 0.0618 Accuracy 0.9827
# Epoch 24 Batch 200 Loss 0.0578 Accuracy 0.9841
# Epoch 24 Batch 250 Loss 0.0537 Accuracy 0.9853
# Epoch 24 Batch 300 Loss 0.0524 Accuracy 0.9856
# Epoch 24 Batch 350 Loss 0.0508 Accuracy 0.9860
# Epoch 24 Loss 0.0488 Accuracy 0.9866
# Time taken for 1 epoch: 23.17007613182068 secs
#
# Epoch 25 Batch 0 Loss 0.0167 Accuracy 0.9949
# Epoch 25 Batch 50 Loss 0.0493 Accuracy 0.9858
# Epoch 25 Batch 100 Loss 0.0548 Accuracy 0.9849
# Epoch 25 Batch 150 Loss 0.0565 Accuracy 0.9841
# Epoch 25 Batch 200 Loss 0.0529 Accuracy 0.9852
# Epoch 25 Batch 250 Loss 0.0494 Accuracy 0.9861
# Epoch 25 Batch 300 Loss 0.0471 Accuracy 0.9868
# Epoch 25 Batch 350 Loss 0.0447 Accuracy 0.9875
# Saving checkpoint for epoch 25 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-5
# Epoch 25 Loss 0.0434 Accuracy 0.9880
# Time taken for 1 epoch: 23.045077800750732 secs
#
# Epoch 26 Batch 0 Loss 0.0168 Accuracy 0.9975
# Epoch 26 Batch 50 Loss 0.0498 Accuracy 0.9861
# Epoch 26 Batch 100 Loss 0.0515 Accuracy 0.9852
# Epoch 26 Batch 150 Loss 0.0540 Accuracy 0.9847
# Epoch 26 Batch 200 Loss 0.0500 Accuracy 0.9858
# Epoch 26 Batch 250 Loss 0.0463 Accuracy 0.9869
# Epoch 26 Batch 300 Loss 0.0446 Accuracy 0.9874
# Epoch 26 Batch 350 Loss 0.0427 Accuracy 0.9880
# Epoch 26 Loss 0.0407 Accuracy 0.9886
# Time taken for 1 epoch: 22.881633758544922 secs
#
# Epoch 27 Batch 0 Loss 0.0248 Accuracy 0.9899
# Epoch 27 Batch 50 Loss 0.0482 Accuracy 0.9868
# Epoch 27 Batch 100 Loss 0.0481 Accuracy 0.9866
# Epoch 27 Batch 150 Loss 0.0504 Accuracy 0.9860
# Epoch 27 Batch 200 Loss 0.0473 Accuracy 0.9868
# Epoch 27 Batch 250 Loss 0.0437 Accuracy 0.9878
# Epoch 27 Batch 300 Loss 0.0426 Accuracy 0.9881
# Epoch 27 Batch 350 Loss 0.0403 Accuracy 0.9886
# Epoch 27 Loss 0.0387 Accuracy 0.9892
# Time taken for 1 epoch: 22.932146072387695 secs
#
# Epoch 28 Batch 0 Loss 0.0182 Accuracy 0.9949
# Epoch 28 Batch 50 Loss 0.0455 Accuracy 0.9866
# Epoch 28 Batch 100 Loss 0.0453 Accuracy 0.9869
# Epoch 28 Batch 150 Loss 0.0473 Accuracy 0.9862
# Epoch 28 Batch 200 Loss 0.0442 Accuracy 0.9871
# Epoch 28 Batch 250 Loss 0.0405 Accuracy 0.9883
# Epoch 28 Batch 300 Loss 0.0388 Accuracy 0.9889
# Epoch 28 Batch 350 Loss 0.0371 Accuracy 0.9894
# Epoch 28 Loss 0.0360 Accuracy 0.9898
# Time taken for 1 epoch: 22.848459720611572 secs
#
# Epoch 29 Batch 0 Loss 0.0142 Accuracy 0.9975
# Epoch 29 Batch 50 Loss 0.0394 Accuracy 0.9890
# Epoch 29 Batch 100 Loss 0.0386 Accuracy 0.9888
# Epoch 29 Batch 150 Loss 0.0416 Accuracy 0.9880
# Epoch 29 Batch 200 Loss 0.0399 Accuracy 0.9887
# Epoch 29 Batch 250 Loss 0.0369 Accuracy 0.9896
# Epoch 29 Batch 300 Loss 0.0355 Accuracy 0.9900
# Epoch 29 Batch 350 Loss 0.0339 Accuracy 0.9905
# Epoch 29 Loss 0.0326 Accuracy 0.9909
# Time taken for 1 epoch: 22.905978202819824 secs
#
# Epoch 30 Batch 0 Loss 0.0349 Accuracy 0.9899
# Epoch 30 Batch 50 Loss 0.0354 Accuracy 0.9903
# Epoch 30 Batch 100 Loss 0.0374 Accuracy 0.9893
# Epoch 30 Batch 150 Loss 0.0400 Accuracy 0.9886
# Epoch 30 Batch 200 Loss 0.0374 Accuracy 0.9894
# Epoch 30 Batch 250 Loss 0.0344 Accuracy 0.9902
# Epoch 30 Batch 300 Loss 0.0330 Accuracy 0.9906
# Epoch 30 Batch 350 Loss 0.0316 Accuracy 0.9910
# Saving checkpoint for epoch 30 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-6
# Epoch 30 Loss 0.0305 Accuracy 0.9914
# Time taken for 1 epoch: 23.017115116119385 secs
#
# Epoch 31 Batch 0 Loss 0.0223 Accuracy 0.9899
# Epoch 31 Batch 50 Loss 0.0385 Accuracy 0.9890
# Epoch 31 Batch 100 Loss 0.0424 Accuracy 0.9884
# Epoch 31 Batch 150 Loss 0.0413 Accuracy 0.9886
# Epoch 31 Batch 200 Loss 0.0378 Accuracy 0.9896
# Epoch 31 Batch 250 Loss 0.0345 Accuracy 0.9904
# Epoch 31 Batch 300 Loss 0.0335 Accuracy 0.9908
# Epoch 31 Batch 350 Loss 0.0317 Accuracy 0.9912
# Epoch 31 Loss 0.0305 Accuracy 0.9916
# Time taken for 1 epoch: 22.847970247268677 secs
#
# Epoch 32 Batch 0 Loss 0.0112 Accuracy 1.0000
# Epoch 32 Batch 50 Loss 0.0285 Accuracy 0.9922
# Epoch 32 Batch 100 Loss 0.0310 Accuracy 0.9915
# Epoch 32 Batch 150 Loss 0.0340 Accuracy 0.9909
# Epoch 32 Batch 200 Loss 0.0320 Accuracy 0.9913
# Epoch 32 Batch 250 Loss 0.0295 Accuracy 0.9919
# Epoch 32 Batch 300 Loss 0.0286 Accuracy 0.9921
# Epoch 32 Batch 350 Loss 0.0278 Accuracy 0.9923
# Epoch 32 Loss 0.0269 Accuracy 0.9925
# Time taken for 1 epoch: 22.847342014312744 secs
#
# Epoch 33 Batch 0 Loss 0.0324 Accuracy 0.9899
# Epoch 33 Batch 50 Loss 0.0380 Accuracy 0.9893
# Epoch 33 Batch 100 Loss 0.0350 Accuracy 0.9898
# Epoch 33 Batch 150 Loss 0.0349 Accuracy 0.9900
# Epoch 33 Batch 200 Loss 0.0326 Accuracy 0.9907
# Epoch 33 Batch 250 Loss 0.0303 Accuracy 0.9914
# Epoch 33 Batch 300 Loss 0.0288 Accuracy 0.9918
# Epoch 33 Batch 350 Loss 0.0272 Accuracy 0.9923
# Epoch 33 Loss 0.0262 Accuracy 0.9925
# Time taken for 1 epoch: 22.828834056854248 secs
#
# Epoch 34 Batch 0 Loss 0.0340 Accuracy 0.9848
# Epoch 34 Batch 50 Loss 0.0304 Accuracy 0.9913
# Epoch 34 Batch 100 Loss 0.0310 Accuracy 0.9910
# Epoch 34 Batch 150 Loss 0.0323 Accuracy 0.9907
# Epoch 34 Batch 200 Loss 0.0304 Accuracy 0.9913
# Epoch 34 Batch 250 Loss 0.0278 Accuracy 0.9921
# Epoch 34 Batch 300 Loss 0.0268 Accuracy 0.9924
# Epoch 34 Batch 350 Loss 0.0254 Accuracy 0.9928
# Epoch 34 Loss 0.0242 Accuracy 0.9931
# Time taken for 1 epoch: 22.813870191574097 secs
#
# Epoch 35 Batch 0 Loss 0.0188 Accuracy 0.9924
# Epoch 35 Batch 50 Loss 0.0274 Accuracy 0.9922
# Epoch 35 Batch 100 Loss 0.0267 Accuracy 0.9924
# Epoch 35 Batch 150 Loss 0.0286 Accuracy 0.9918
# Epoch 35 Batch 200 Loss 0.0271 Accuracy 0.9924
# Epoch 35 Batch 250 Loss 0.0255 Accuracy 0.9929
# Epoch 35 Batch 300 Loss 0.0245 Accuracy 0.9931
# Epoch 35 Batch 350 Loss 0.0236 Accuracy 0.9933
# Saving checkpoint for epoch 35 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-7
# Epoch 35 Loss 0.0230 Accuracy 0.9935
# Time taken for 1 epoch: 22.957980632781982 secs
#
# Epoch 36 Batch 0 Loss 0.0145 Accuracy 0.9975
# Epoch 36 Batch 50 Loss 0.0256 Accuracy 0.9924
# Epoch 36 Batch 100 Loss 0.0282 Accuracy 0.9920
# Epoch 36 Batch 150 Loss 0.0283 Accuracy 0.9920
# Epoch 36 Batch 200 Loss 0.0283 Accuracy 0.9921
# Epoch 36 Batch 250 Loss 0.0265 Accuracy 0.9926
# Epoch 36 Batch 300 Loss 0.0256 Accuracy 0.9929
# Epoch 36 Batch 350 Loss 0.0246 Accuracy 0.9931
# Epoch 36 Loss 0.0237 Accuracy 0.9934
# Time taken for 1 epoch: 22.836494207382202 secs
#
# Epoch 37 Batch 0 Loss 0.0390 Accuracy 0.9848
# Epoch 37 Batch 50 Loss 0.0284 Accuracy 0.9914
# Epoch 37 Batch 100 Loss 0.0281 Accuracy 0.9918
# Epoch 37 Batch 150 Loss 0.0283 Accuracy 0.9918
# Epoch 37 Batch 200 Loss 0.0268 Accuracy 0.9923
# Epoch 37 Batch 250 Loss 0.0246 Accuracy 0.9930
# Epoch 37 Batch 300 Loss 0.0243 Accuracy 0.9931
# Epoch 37 Batch 350 Loss 0.0234 Accuracy 0.9934
# Epoch 37 Loss 0.0224 Accuracy 0.9937
# Time taken for 1 epoch: 22.77708148956299 secs
#
# Epoch 38 Batch 0 Loss 0.0136 Accuracy 0.9949
# Epoch 38 Batch 50 Loss 0.0248 Accuracy 0.9937
# Epoch 38 Batch 100 Loss 0.0260 Accuracy 0.9931
# Epoch 38 Batch 150 Loss 0.0263 Accuracy 0.9928
# Epoch 38 Batch 200 Loss 0.0249 Accuracy 0.9932
# Epoch 38 Batch 250 Loss 0.0231 Accuracy 0.9936
# Epoch 38 Batch 300 Loss 0.0222 Accuracy 0.9938
# Epoch 38 Batch 350 Loss 0.0212 Accuracy 0.9942
# Epoch 38 Loss 0.0206 Accuracy 0.9944
# Time taken for 1 epoch: 22.834583044052124 secs
#
# Epoch 39 Batch 0 Loss 0.0091 Accuracy 0.9975
# Epoch 39 Batch 50 Loss 0.0235 Accuracy 0.9932
# Epoch 39 Batch 100 Loss 0.0245 Accuracy 0.9929
# Epoch 39 Batch 150 Loss 0.0262 Accuracy 0.9926
# Epoch 39 Batch 200 Loss 0.0246 Accuracy 0.9931
# Epoch 39 Batch 250 Loss 0.0227 Accuracy 0.9937
# Epoch 39 Batch 300 Loss 0.0221 Accuracy 0.9938
# Epoch 39 Batch 350 Loss 0.0212 Accuracy 0.9940
# Epoch 39 Loss 0.0205 Accuracy 0.9943
# Time taken for 1 epoch: 22.832648754119873 secs
#
# Epoch 40 Batch 0 Loss 0.0114 Accuracy 0.9975
# Epoch 40 Batch 50 Loss 0.0259 Accuracy 0.9930
# Epoch 40 Batch 100 Loss 0.0261 Accuracy 0.9929
# Epoch 40 Batch 150 Loss 0.0267 Accuracy 0.9928
# Epoch 40 Batch 200 Loss 0.0250 Accuracy 0.9933
# Epoch 40 Batch 250 Loss 0.0231 Accuracy 0.9938
# Epoch 40 Batch 300 Loss 0.0222 Accuracy 0.9940
# Epoch 40 Batch 350 Loss 0.0210 Accuracy 0.9943
# Saving checkpoint for epoch 40 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-8
# Epoch 40 Loss 0.0202 Accuracy 0.9945
# Time taken for 1 epoch: 23.041871070861816 secs
#
# Epoch 41 Batch 0 Loss 0.0121 Accuracy 0.9975
# Epoch 41 Batch 50 Loss 0.0220 Accuracy 0.9942
# Epoch 41 Batch 100 Loss 0.0217 Accuracy 0.9940
# Epoch 41 Batch 150 Loss 0.0232 Accuracy 0.9934
# Epoch 41 Batch 200 Loss 0.0231 Accuracy 0.9934
# Epoch 41 Batch 250 Loss 0.0206 Accuracy 0.9942
# Epoch 41 Batch 300 Loss 0.0200 Accuracy 0.9944
# Epoch 41 Batch 350 Loss 0.0192 Accuracy 0.9946
# Epoch 41 Loss 0.0184 Accuracy 0.9948
# Time taken for 1 epoch: 22.801677465438843 secs
#
# Epoch 42 Batch 0 Loss 0.0166 Accuracy 0.9924
# Epoch 42 Batch 50 Loss 0.0204 Accuracy 0.9941
# Epoch 42 Batch 100 Loss 0.0214 Accuracy 0.9937
# Epoch 42 Batch 150 Loss 0.0231 Accuracy 0.9933
# Epoch 42 Batch 200 Loss 0.0220 Accuracy 0.9936
# Epoch 42 Batch 250 Loss 0.0207 Accuracy 0.9941
# Epoch 42 Batch 300 Loss 0.0201 Accuracy 0.9942
# Epoch 42 Batch 350 Loss 0.0194 Accuracy 0.9944
# Epoch 42 Loss 0.0186 Accuracy 0.9946
# Time taken for 1 epoch: 22.829184532165527 secs
#
# Epoch 43 Batch 0 Loss 0.0197 Accuracy 0.9975
# Epoch 43 Batch 50 Loss 0.0194 Accuracy 0.9946
# Epoch 43 Batch 100 Loss 0.0207 Accuracy 0.9940
# Epoch 43 Batch 150 Loss 0.0213 Accuracy 0.9939
# Epoch 43 Batch 200 Loss 0.0198 Accuracy 0.9944
# Epoch 43 Batch 250 Loss 0.0186 Accuracy 0.9948
# Epoch 43 Batch 300 Loss 0.0183 Accuracy 0.9949
# Epoch 43 Batch 350 Loss 0.0175 Accuracy 0.9950
# Epoch 43 Loss 0.0171 Accuracy 0.9952
# Time taken for 1 epoch: 22.820733070373535 secs
#
# Epoch 44 Batch 0 Loss 0.0092 Accuracy 0.9975
# Epoch 44 Batch 50 Loss 0.0176 Accuracy 0.9950
# Epoch 44 Batch 100 Loss 0.0180 Accuracy 0.9950
# Epoch 44 Batch 150 Loss 0.0190 Accuracy 0.9947
# Epoch 44 Batch 200 Loss 0.0179 Accuracy 0.9950
# Epoch 44 Batch 250 Loss 0.0173 Accuracy 0.9952
# Epoch 44 Batch 300 Loss 0.0168 Accuracy 0.9953
# Epoch 44 Batch 350 Loss 0.0162 Accuracy 0.9955
# Epoch 44 Loss 0.0155 Accuracy 0.9957
# Time taken for 1 epoch: 22.842977046966553 secs
#
# Epoch 45 Batch 0 Loss 0.0230 Accuracy 0.9949
# Epoch 45 Batch 50 Loss 0.0201 Accuracy 0.9937
# Epoch 45 Batch 100 Loss 0.0204 Accuracy 0.9940
# Epoch 45 Batch 150 Loss 0.0209 Accuracy 0.9938
# Epoch 45 Batch 200 Loss 0.0195 Accuracy 0.9943
# Epoch 45 Batch 250 Loss 0.0183 Accuracy 0.9947
# Epoch 45 Batch 300 Loss 0.0177 Accuracy 0.9949
# Epoch 45 Batch 350 Loss 0.0168 Accuracy 0.9952
# Saving checkpoint for epoch 45 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-9
# Epoch 45 Loss 0.0161 Accuracy 0.9953
# Time taken for 1 epoch: 23.026408672332764 secs
#
# Epoch 46 Batch 0 Loss 0.0102 Accuracy 0.9975
# Epoch 46 Batch 50 Loss 0.0180 Accuracy 0.9957
# Epoch 46 Batch 100 Loss 0.0187 Accuracy 0.9951
# Epoch 46 Batch 150 Loss 0.0190 Accuracy 0.9949
# Epoch 46 Batch 200 Loss 0.0185 Accuracy 0.9951
# Epoch 46 Batch 250 Loss 0.0173 Accuracy 0.9954
# Epoch 46 Batch 300 Loss 0.0167 Accuracy 0.9955
# Epoch 46 Batch 350 Loss 0.0159 Accuracy 0.9957
# Epoch 46 Loss 0.0154 Accuracy 0.9959
# Time taken for 1 epoch: 22.86420965194702 secs
#
# Epoch 47 Batch 0 Loss 0.0227 Accuracy 0.9873
# Epoch 47 Batch 50 Loss 0.0187 Accuracy 0.9954
# Epoch 47 Batch 100 Loss 0.0173 Accuracy 0.9954
# Epoch 47 Batch 150 Loss 0.0183 Accuracy 0.9949
# Epoch 47 Batch 200 Loss 0.0174 Accuracy 0.9951
# Epoch 47 Batch 250 Loss 0.0163 Accuracy 0.9954
# Epoch 47 Batch 300 Loss 0.0170 Accuracy 0.9953
# Epoch 47 Batch 350 Loss 0.0163 Accuracy 0.9955
# Epoch 47 Loss 0.0157 Accuracy 0.9957
# Time taken for 1 epoch: 22.792361736297607 secs
#
# Epoch 48 Batch 0 Loss 0.0032 Accuracy 1.0000
# Epoch 48 Batch 50 Loss 0.0189 Accuracy 0.9947
# Epoch 48 Batch 100 Loss 0.0178 Accuracy 0.9948
# Epoch 48 Batch 150 Loss 0.0175 Accuracy 0.9949
# Epoch 48 Batch 200 Loss 0.0167 Accuracy 0.9952
# Epoch 48 Batch 250 Loss 0.0155 Accuracy 0.9955
# Epoch 48 Batch 300 Loss 0.0150 Accuracy 0.9957
# Epoch 48 Batch 350 Loss 0.0142 Accuracy 0.9959
# Epoch 48 Loss 0.0138 Accuracy 0.9960
# Time taken for 1 epoch: 22.869381427764893 secs
#
# Epoch 49 Batch 0 Loss 0.0142 Accuracy 0.9949
# Epoch 49 Batch 50 Loss 0.0165 Accuracy 0.9952
# Epoch 49 Batch 100 Loss 0.0177 Accuracy 0.9953
# Epoch 49 Batch 150 Loss 0.0183 Accuracy 0.9951
# Epoch 49 Batch 200 Loss 0.0171 Accuracy 0.9954
# Epoch 49 Batch 250 Loss 0.0159 Accuracy 0.9956
# Epoch 49 Batch 300 Loss 0.0153 Accuracy 0.9957
# Epoch 49 Batch 350 Loss 0.0150 Accuracy 0.9959
# Epoch 49 Loss 0.0145 Accuracy 0.9960
# Time taken for 1 epoch: 22.828569173812866 secs
#
# Epoch 50 Batch 0 Loss 0.0117 Accuracy 0.9949
# Epoch 50 Batch 50 Loss 0.0159 Accuracy 0.9956
# Epoch 50 Batch 100 Loss 0.0149 Accuracy 0.9958
# Epoch 50 Batch 150 Loss 0.0170 Accuracy 0.9953
# Epoch 50 Batch 200 Loss 0.0157 Accuracy 0.9955
# Epoch 50 Batch 250 Loss 0.0147 Accuracy 0.9958
# Epoch 50 Batch 300 Loss 0.0141 Accuracy 0.9960
# Epoch 50 Batch 350 Loss 0.0136 Accuracy 0.9961
# Saving checkpoint for epoch 50 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-10
# Epoch 50 Loss 0.0131 Accuracy 0.9963
# Time taken for 1 epoch: 23.02392339706421 secs
#
# Epoch 51 Batch 0 Loss 0.0037 Accuracy 1.0000
# Epoch 51 Batch 50 Loss 0.0165 Accuracy 0.9958
# Epoch 51 Batch 100 Loss 0.0178 Accuracy 0.9950
# Epoch 51 Batch 150 Loss 0.0186 Accuracy 0.9947
# Epoch 51 Batch 200 Loss 0.0180 Accuracy 0.9950
# Epoch 51 Batch 250 Loss 0.0166 Accuracy 0.9954
# Epoch 51 Batch 300 Loss 0.0160 Accuracy 0.9955
# Epoch 51 Batch 350 Loss 0.0153 Accuracy 0.9957
# Epoch 51 Loss 0.0147 Accuracy 0.9959
# Time taken for 1 epoch: 22.880175828933716 secs
#
# Epoch 52 Batch 0 Loss 0.0024 Accuracy 1.0000
# Epoch 52 Batch 50 Loss 0.0142 Accuracy 0.9959
# Epoch 52 Batch 100 Loss 0.0142 Accuracy 0.9958
# Epoch 52 Batch 150 Loss 0.0150 Accuracy 0.9958
# Epoch 52 Batch 200 Loss 0.0148 Accuracy 0.9958
# Epoch 52 Batch 250 Loss 0.0139 Accuracy 0.9961
# Epoch 52 Batch 300 Loss 0.0135 Accuracy 0.9963
# Epoch 52 Batch 350 Loss 0.0131 Accuracy 0.9964
# Epoch 52 Loss 0.0126 Accuracy 0.9965
# Time taken for 1 epoch: 22.823427438735962 secs
#
# Epoch 53 Batch 0 Loss 0.0023 Accuracy 1.0000
# Epoch 53 Batch 50 Loss 0.0130 Accuracy 0.9966
# Epoch 53 Batch 100 Loss 0.0145 Accuracy 0.9955
# Epoch 53 Batch 150 Loss 0.0149 Accuracy 0.9955
# Epoch 53 Batch 200 Loss 0.0143 Accuracy 0.9958
# Epoch 53 Batch 250 Loss 0.0136 Accuracy 0.9960
# Epoch 53 Batch 300 Loss 0.0134 Accuracy 0.9961
# Epoch 53 Batch 350 Loss 0.0126 Accuracy 0.9963
# Epoch 53 Loss 0.0123 Accuracy 0.9965
# Time taken for 1 epoch: 22.85890793800354 secs
#
# Epoch 54 Batch 0 Loss 0.0058 Accuracy 1.0000
# Epoch 54 Batch 50 Loss 0.0139 Accuracy 0.9960
# Epoch 54 Batch 100 Loss 0.0145 Accuracy 0.9959
# Epoch 54 Batch 150 Loss 0.0148 Accuracy 0.9959
# Epoch 54 Batch 200 Loss 0.0142 Accuracy 0.9961
# Epoch 54 Batch 250 Loss 0.0132 Accuracy 0.9964
# Epoch 54 Batch 300 Loss 0.0128 Accuracy 0.9965
# Epoch 54 Batch 350 Loss 0.0123 Accuracy 0.9966
# Epoch 54 Loss 0.0119 Accuracy 0.9967
# Time taken for 1 epoch: 22.887470722198486 secs
#
# Epoch 55 Batch 0 Loss 0.0164 Accuracy 0.9924
# Epoch 55 Batch 50 Loss 0.0175 Accuracy 0.9953
# Epoch 55 Batch 100 Loss 0.0153 Accuracy 0.9959
# Epoch 55 Batch 150 Loss 0.0152 Accuracy 0.9959
# Epoch 55 Batch 200 Loss 0.0149 Accuracy 0.9960
# Epoch 55 Batch 250 Loss 0.0135 Accuracy 0.9964
# Epoch 55 Batch 300 Loss 0.0130 Accuracy 0.9965
# Epoch 55 Batch 350 Loss 0.0124 Accuracy 0.9966
# Saving checkpoint for epoch 55 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-11
# Epoch 55 Loss 0.0119 Accuracy 0.9968
# Time taken for 1 epoch: 22.930104970932007 secs
#
# Epoch 56 Batch 0 Loss 0.0055 Accuracy 1.0000
# Epoch 56 Batch 50 Loss 0.0144 Accuracy 0.9962
# Epoch 56 Batch 100 Loss 0.0160 Accuracy 0.9957
# Epoch 56 Batch 150 Loss 0.0162 Accuracy 0.9956
# Epoch 56 Batch 200 Loss 0.0156 Accuracy 0.9957
# Epoch 56 Batch 250 Loss 0.0139 Accuracy 0.9962
# Epoch 56 Batch 300 Loss 0.0134 Accuracy 0.9963
# Epoch 56 Batch 350 Loss 0.0126 Accuracy 0.9965
# Epoch 56 Loss 0.0122 Accuracy 0.9966
# Time taken for 1 epoch: 22.83206009864807 secs
#
# Epoch 57 Batch 0 Loss 0.0027 Accuracy 1.0000
# Epoch 57 Batch 50 Loss 0.0121 Accuracy 0.9965
# Epoch 57 Batch 100 Loss 0.0133 Accuracy 0.9963
# Epoch 57 Batch 150 Loss 0.0140 Accuracy 0.9961
# Epoch 57 Batch 200 Loss 0.0137 Accuracy 0.9961
# Epoch 57 Batch 250 Loss 0.0128 Accuracy 0.9963
# Epoch 57 Batch 300 Loss 0.0124 Accuracy 0.9965
# Epoch 57 Batch 350 Loss 0.0117 Accuracy 0.9967
# Epoch 57 Loss 0.0112 Accuracy 0.9968
# Time taken for 1 epoch: 22.91505193710327 secs
#
# Epoch 58 Batch 0 Loss 0.0133 Accuracy 0.9949
# Epoch 58 Batch 50 Loss 0.0127 Accuracy 0.9966
# Epoch 58 Batch 100 Loss 0.0118 Accuracy 0.9967
# Epoch 58 Batch 150 Loss 0.0125 Accuracy 0.9965
# Epoch 58 Batch 200 Loss 0.0121 Accuracy 0.9966
# Epoch 58 Batch 250 Loss 0.0118 Accuracy 0.9967
# Epoch 58 Batch 300 Loss 0.0115 Accuracy 0.9968
# Epoch 58 Batch 350 Loss 0.0110 Accuracy 0.9970
# Epoch 58 Loss 0.0105 Accuracy 0.9971
# Time taken for 1 epoch: 23.05732226371765 secs
#
# Epoch 59 Batch 0 Loss 0.0046 Accuracy 0.9975
# Epoch 59 Batch 50 Loss 0.0096 Accuracy 0.9974
# Epoch 59 Batch 100 Loss 0.0108 Accuracy 0.9968
# Epoch 59 Batch 150 Loss 0.0116 Accuracy 0.9966
# Epoch 59 Batch 200 Loss 0.0122 Accuracy 0.9965
# Epoch 59 Batch 250 Loss 0.0119 Accuracy 0.9967
# Epoch 59 Batch 300 Loss 0.0114 Accuracy 0.9968
# Epoch 59 Batch 350 Loss 0.0112 Accuracy 0.9969
# Epoch 59 Loss 0.0109 Accuracy 0.9970
# Time taken for 1 epoch: 23.07817554473877 secs
#
# Epoch 60 Batch 0 Loss 0.0027 Accuracy 1.0000
# Epoch 60 Batch 50 Loss 0.0129 Accuracy 0.9967
# Epoch 60 Batch 100 Loss 0.0130 Accuracy 0.9964
# Epoch 60 Batch 150 Loss 0.0127 Accuracy 0.9965
# Epoch 60 Batch 200 Loss 0.0120 Accuracy 0.9965
# Epoch 60 Batch 250 Loss 0.0113 Accuracy 0.9968
# Epoch 60 Batch 300 Loss 0.0110 Accuracy 0.9968
# Epoch 60 Batch 350 Loss 0.0105 Accuracy 0.9969
# Saving checkpoint for epoch 60 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-12
# Epoch 60 Loss 0.0102 Accuracy 0.9970
# Time taken for 1 epoch: 23.07216167449951 secs
#
# Epoch 61 Batch 0 Loss 0.0021 Accuracy 1.0000
# Epoch 61 Batch 50 Loss 0.0118 Accuracy 0.9969
# Epoch 61 Batch 100 Loss 0.0111 Accuracy 0.9971
# Epoch 61 Batch 150 Loss 0.0117 Accuracy 0.9968
# Epoch 61 Batch 200 Loss 0.0111 Accuracy 0.9970
# Epoch 61 Batch 250 Loss 0.0103 Accuracy 0.9972
# Epoch 61 Batch 300 Loss 0.0105 Accuracy 0.9971
# Epoch 61 Batch 350 Loss 0.0101 Accuracy 0.9972
# Epoch 61 Loss 0.0097 Accuracy 0.9973
# Time taken for 1 epoch: 22.895804166793823 secs
#
# Epoch 62 Batch 0 Loss 0.0026 Accuracy 1.0000
# Epoch 62 Batch 50 Loss 0.0150 Accuracy 0.9960
# Epoch 62 Batch 100 Loss 0.0142 Accuracy 0.9963
# Epoch 62 Batch 150 Loss 0.0140 Accuracy 0.9963
# Epoch 62 Batch 200 Loss 0.0133 Accuracy 0.9964
# Epoch 62 Batch 250 Loss 0.0122 Accuracy 0.9967
# Epoch 62 Batch 300 Loss 0.0118 Accuracy 0.9968
# Epoch 62 Batch 350 Loss 0.0114 Accuracy 0.9969
# Epoch 62 Loss 0.0109 Accuracy 0.9970
# Time taken for 1 epoch: 22.96582341194153 secs
#
# Epoch 63 Batch 0 Loss 0.0218 Accuracy 0.9949
# Epoch 63 Batch 50 Loss 0.0120 Accuracy 0.9969
# Epoch 63 Batch 100 Loss 0.0128 Accuracy 0.9965
# Epoch 63 Batch 150 Loss 0.0134 Accuracy 0.9964
# Epoch 63 Batch 200 Loss 0.0127 Accuracy 0.9967
# Epoch 63 Batch 250 Loss 0.0121 Accuracy 0.9969
# Epoch 63 Batch 300 Loss 0.0115 Accuracy 0.9970
# Epoch 63 Batch 350 Loss 0.0108 Accuracy 0.9971
# Epoch 63 Loss 0.0105 Accuracy 0.9972
# Time taken for 1 epoch: 22.876304149627686 secs
#
# Epoch 64 Batch 0 Loss 0.0030 Accuracy 1.0000
# Epoch 64 Batch 50 Loss 0.0142 Accuracy 0.9961
# Epoch 64 Batch 100 Loss 0.0131 Accuracy 0.9962
# Epoch 64 Batch 150 Loss 0.0124 Accuracy 0.9964
# Epoch 64 Batch 200 Loss 0.0122 Accuracy 0.9966
# Epoch 64 Batch 250 Loss 0.0111 Accuracy 0.9969
# Epoch 64 Batch 300 Loss 0.0107 Accuracy 0.9971
# Epoch 64 Batch 350 Loss 0.0102 Accuracy 0.9972
# Epoch 64 Loss 0.0098 Accuracy 0.9973
# Time taken for 1 epoch: 22.85033345222473 secs
#
# Epoch 65 Batch 0 Loss 0.0024 Accuracy 1.0000
# Epoch 65 Batch 50 Loss 0.0111 Accuracy 0.9969
# Epoch 65 Batch 100 Loss 0.0107 Accuracy 0.9969
# Epoch 65 Batch 150 Loss 0.0114 Accuracy 0.9968
# Epoch 65 Batch 200 Loss 0.0107 Accuracy 0.9970
# Epoch 65 Batch 250 Loss 0.0103 Accuracy 0.9971
# Epoch 65 Batch 300 Loss 0.0103 Accuracy 0.9970
# Epoch 65 Batch 350 Loss 0.0098 Accuracy 0.9971
# Saving checkpoint for epoch 65 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-13
# Epoch 65 Loss 0.0096 Accuracy 0.9972
# Time taken for 1 epoch: 23.098149299621582 secs
#
# Epoch 66 Batch 0 Loss 0.0031 Accuracy 0.9975
# Epoch 66 Batch 50 Loss 0.0103 Accuracy 0.9972
# Epoch 66 Batch 100 Loss 0.0117 Accuracy 0.9966
# Epoch 66 Batch 150 Loss 0.0112 Accuracy 0.9968
# Epoch 66 Batch 200 Loss 0.0103 Accuracy 0.9971
# Epoch 66 Batch 250 Loss 0.0095 Accuracy 0.9973
# Epoch 66 Batch 300 Loss 0.0091 Accuracy 0.9974
# Epoch 66 Batch 350 Loss 0.0088 Accuracy 0.9974
# Epoch 66 Loss 0.0085 Accuracy 0.9975
# Time taken for 1 epoch: 22.91604995727539 secs
#
# Epoch 67 Batch 0 Loss 0.0155 Accuracy 0.9975
# Epoch 67 Batch 50 Loss 0.0117 Accuracy 0.9966
# Epoch 67 Batch 100 Loss 0.0123 Accuracy 0.9966
# Epoch 67 Batch 150 Loss 0.0125 Accuracy 0.9964
# Epoch 67 Batch 200 Loss 0.0121 Accuracy 0.9966
# Epoch 67 Batch 250 Loss 0.0113 Accuracy 0.9969
# Epoch 67 Batch 300 Loss 0.0106 Accuracy 0.9970
# Epoch 67 Batch 350 Loss 0.0099 Accuracy 0.9972
# Epoch 67 Loss 0.0094 Accuracy 0.9973
# Time taken for 1 epoch: 22.88133144378662 secs
#
# Epoch 68 Batch 0 Loss 0.0074 Accuracy 0.9975
# Epoch 68 Batch 50 Loss 0.0137 Accuracy 0.9967
# Epoch 68 Batch 100 Loss 0.0124 Accuracy 0.9968
# Epoch 68 Batch 150 Loss 0.0116 Accuracy 0.9968
# Epoch 68 Batch 200 Loss 0.0112 Accuracy 0.9970
# Epoch 68 Batch 250 Loss 0.0105 Accuracy 0.9972
# Epoch 68 Batch 300 Loss 0.0099 Accuracy 0.9973
# Epoch 68 Batch 350 Loss 0.0095 Accuracy 0.9974
# Epoch 68 Loss 0.0091 Accuracy 0.9975
# Time taken for 1 epoch: 22.971728801727295 secs
#
# Epoch 69 Batch 0 Loss 0.0080 Accuracy 0.9975
# Epoch 69 Batch 50 Loss 0.0088 Accuracy 0.9980
# Epoch 69 Batch 100 Loss 0.0113 Accuracy 0.9969
# Epoch 69 Batch 150 Loss 0.0117 Accuracy 0.9969
# Epoch 69 Batch 200 Loss 0.0113 Accuracy 0.9970
# Epoch 69 Batch 250 Loss 0.0106 Accuracy 0.9972
# Epoch 69 Batch 300 Loss 0.0102 Accuracy 0.9972
# Epoch 69 Batch 350 Loss 0.0095 Accuracy 0.9974
# Epoch 69 Loss 0.0093 Accuracy 0.9975
# Time taken for 1 epoch: 22.81662392616272 secs
#
# Epoch 70 Batch 0 Loss 0.0042 Accuracy 1.0000
# Epoch 70 Batch 50 Loss 0.0099 Accuracy 0.9975
# Epoch 70 Batch 100 Loss 0.0110 Accuracy 0.9969
# Epoch 70 Batch 150 Loss 0.0108 Accuracy 0.9968
# Epoch 70 Batch 200 Loss 0.0104 Accuracy 0.9970
# Epoch 70 Batch 250 Loss 0.0096 Accuracy 0.9972
# Epoch 70 Batch 300 Loss 0.0093 Accuracy 0.9973
# Epoch 70 Batch 350 Loss 0.0089 Accuracy 0.9974
# Saving checkpoint for epoch 70 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-14
# Epoch 70 Loss 0.0085 Accuracy 0.9975
# Time taken for 1 epoch: 23.028014421463013 secs
#
# Epoch 71 Batch 0 Loss 0.0110 Accuracy 0.9949
# Epoch 71 Batch 50 Loss 0.0097 Accuracy 0.9975
# Epoch 71 Batch 100 Loss 0.0100 Accuracy 0.9972
# Epoch 71 Batch 150 Loss 0.0103 Accuracy 0.9970
# Epoch 71 Batch 200 Loss 0.0099 Accuracy 0.9971
# Epoch 71 Batch 250 Loss 0.0090 Accuracy 0.9974
# Epoch 71 Batch 300 Loss 0.0086 Accuracy 0.9975
# Epoch 71 Batch 350 Loss 0.0082 Accuracy 0.9976
# Epoch 71 Loss 0.0080 Accuracy 0.9977
# Time taken for 1 epoch: 22.89885640144348 secs
#
# Epoch 72 Batch 0 Loss 0.0009 Accuracy 1.0000
# Epoch 72 Batch 50 Loss 0.0081 Accuracy 0.9977
# Epoch 72 Batch 100 Loss 0.0103 Accuracy 0.9971
# Epoch 72 Batch 150 Loss 0.0103 Accuracy 0.9972
# Epoch 72 Batch 200 Loss 0.0100 Accuracy 0.9973
# Epoch 72 Batch 250 Loss 0.0093 Accuracy 0.9975
# Epoch 72 Batch 300 Loss 0.0091 Accuracy 0.9975
# Epoch 72 Batch 350 Loss 0.0088 Accuracy 0.9975
# Epoch 72 Loss 0.0085 Accuracy 0.9976
# Time taken for 1 epoch: 22.927043676376343 secs
#
# Epoch 73 Batch 0 Loss 0.0018 Accuracy 1.0000
# Epoch 73 Batch 50 Loss 0.0109 Accuracy 0.9975
# Epoch 73 Batch 100 Loss 0.0113 Accuracy 0.9972
# Epoch 73 Batch 150 Loss 0.0109 Accuracy 0.9971
# Epoch 73 Batch 200 Loss 0.0106 Accuracy 0.9972
# Epoch 73 Batch 250 Loss 0.0100 Accuracy 0.9973
# Epoch 73 Batch 300 Loss 0.0101 Accuracy 0.9973
# Epoch 73 Batch 350 Loss 0.0098 Accuracy 0.9973
# Epoch 73 Loss 0.0094 Accuracy 0.9974
# Time taken for 1 epoch: 22.914572954177856 secs
#
# Epoch 74 Batch 0 Loss 0.0107 Accuracy 0.9975
# Epoch 74 Batch 50 Loss 0.0085 Accuracy 0.9976
# Epoch 74 Batch 100 Loss 0.0086 Accuracy 0.9976
# Epoch 74 Batch 150 Loss 0.0096 Accuracy 0.9973
# Epoch 74 Batch 200 Loss 0.0093 Accuracy 0.9974
# Epoch 74 Batch 250 Loss 0.0085 Accuracy 0.9976
# Epoch 74 Batch 300 Loss 0.0084 Accuracy 0.9977
# Epoch 74 Batch 350 Loss 0.0080 Accuracy 0.9978
# Epoch 74 Loss 0.0076 Accuracy 0.9979
# Time taken for 1 epoch: 22.91614031791687 secs
#
# Epoch 75 Batch 0 Loss 0.0008 Accuracy 1.0000
# Epoch 75 Batch 50 Loss 0.0097 Accuracy 0.9975
# Epoch 75 Batch 100 Loss 0.0088 Accuracy 0.9975
# Epoch 75 Batch 150 Loss 0.0094 Accuracy 0.9974
# Epoch 75 Batch 200 Loss 0.0093 Accuracy 0.9974
# Epoch 75 Batch 250 Loss 0.0089 Accuracy 0.9975
# Epoch 75 Batch 300 Loss 0.0088 Accuracy 0.9975
# Epoch 75 Batch 350 Loss 0.0084 Accuracy 0.9976
# Saving checkpoint for epoch 75 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-15
# Epoch 75 Loss 0.0080 Accuracy 0.9977
# Time taken for 1 epoch: 23.083094835281372 secs
#
# Epoch 76 Batch 0 Loss 0.0102 Accuracy 0.9975
# Epoch 76 Batch 50 Loss 0.0082 Accuracy 0.9980
# Epoch 76 Batch 100 Loss 0.0081 Accuracy 0.9978
# Epoch 76 Batch 150 Loss 0.0086 Accuracy 0.9977
# Epoch 76 Batch 200 Loss 0.0082 Accuracy 0.9978
# Epoch 76 Batch 250 Loss 0.0079 Accuracy 0.9979
# Epoch 76 Batch 300 Loss 0.0078 Accuracy 0.9979
# Epoch 76 Batch 350 Loss 0.0075 Accuracy 0.9980
# Epoch 76 Loss 0.0076 Accuracy 0.9980
# Time taken for 1 epoch: 22.912015199661255 secs
#
# Epoch 77 Batch 0 Loss 0.0006 Accuracy 1.0000
# Epoch 77 Batch 50 Loss 0.0097 Accuracy 0.9979
# Epoch 77 Batch 100 Loss 0.0095 Accuracy 0.9975
# Epoch 77 Batch 150 Loss 0.0088 Accuracy 0.9976
# Epoch 77 Batch 200 Loss 0.0089 Accuracy 0.9977
# Epoch 77 Batch 250 Loss 0.0083 Accuracy 0.9978
# Epoch 77 Batch 300 Loss 0.0079 Accuracy 0.9978
# Epoch 77 Batch 350 Loss 0.0074 Accuracy 0.9980
# Epoch 77 Loss 0.0070 Accuracy 0.9981
# Time taken for 1 epoch: 22.93514370918274 secs
#
# Epoch 78 Batch 0 Loss 0.0009 Accuracy 1.0000
# Epoch 78 Batch 50 Loss 0.0080 Accuracy 0.9978
# Epoch 78 Batch 100 Loss 0.0085 Accuracy 0.9977
# Epoch 78 Batch 150 Loss 0.0089 Accuracy 0.9975
# Epoch 78 Batch 200 Loss 0.0087 Accuracy 0.9976
# Epoch 78 Batch 250 Loss 0.0082 Accuracy 0.9978
# Epoch 78 Batch 300 Loss 0.0080 Accuracy 0.9978
# Epoch 78 Batch 350 Loss 0.0076 Accuracy 0.9979
# Epoch 78 Loss 0.0074 Accuracy 0.9980
# Time taken for 1 epoch: 22.90580129623413 secs
#
# Epoch 79 Batch 0 Loss 0.0018 Accuracy 1.0000
# Epoch 79 Batch 50 Loss 0.0106 Accuracy 0.9972
# Epoch 79 Batch 100 Loss 0.0097 Accuracy 0.9974
# Epoch 79 Batch 150 Loss 0.0095 Accuracy 0.9973
# Epoch 79 Batch 200 Loss 0.0091 Accuracy 0.9974
# Epoch 79 Batch 250 Loss 0.0081 Accuracy 0.9977
# Epoch 79 Batch 300 Loss 0.0079 Accuracy 0.9977
# Epoch 79 Batch 350 Loss 0.0075 Accuracy 0.9978
# Epoch 79 Loss 0.0072 Accuracy 0.9979
# Time taken for 1 epoch: 22.899842262268066 secs
#
# Epoch 80 Batch 0 Loss 0.0050 Accuracy 0.9975
# Epoch 80 Batch 50 Loss 0.0084 Accuracy 0.9980
# Epoch 80 Batch 100 Loss 0.0085 Accuracy 0.9978
# Epoch 80 Batch 150 Loss 0.0088 Accuracy 0.9977
# Epoch 80 Batch 200 Loss 0.0084 Accuracy 0.9978
# Epoch 80 Batch 250 Loss 0.0080 Accuracy 0.9979
# Epoch 80 Batch 300 Loss 0.0079 Accuracy 0.9979
# Epoch 80 Batch 350 Loss 0.0075 Accuracy 0.9980
# Saving checkpoint for epoch 80 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-16
# Epoch 80 Loss 0.0072 Accuracy 0.9981
# Time taken for 1 epoch: 23.108548164367676 secs
#
# Epoch 81 Batch 0 Loss 0.0137 Accuracy 0.9924
# Epoch 81 Batch 50 Loss 0.0104 Accuracy 0.9967
# Epoch 81 Batch 100 Loss 0.0088 Accuracy 0.9973
# Epoch 81 Batch 150 Loss 0.0088 Accuracy 0.9974
# Epoch 81 Batch 200 Loss 0.0086 Accuracy 0.9975
# Epoch 81 Batch 250 Loss 0.0084 Accuracy 0.9976
# Epoch 81 Batch 300 Loss 0.0079 Accuracy 0.9977
# Epoch 81 Batch 350 Loss 0.0073 Accuracy 0.9979
# Epoch 81 Loss 0.0071 Accuracy 0.9980
# Time taken for 1 epoch: 23.301403522491455 secs
#
# Epoch 82 Batch 0 Loss 0.0012 Accuracy 1.0000
# Epoch 82 Batch 50 Loss 0.0092 Accuracy 0.9976
# Epoch 82 Batch 100 Loss 0.0091 Accuracy 0.9975
# Epoch 82 Batch 150 Loss 0.0095 Accuracy 0.9974
# Epoch 82 Batch 200 Loss 0.0087 Accuracy 0.9976
# Epoch 82 Batch 250 Loss 0.0078 Accuracy 0.9978
# Epoch 82 Batch 300 Loss 0.0076 Accuracy 0.9978
# Epoch 82 Batch 350 Loss 0.0072 Accuracy 0.9979
# Epoch 82 Loss 0.0070 Accuracy 0.9980
# Time taken for 1 epoch: 22.932792901992798 secs
#
# Epoch 83 Batch 0 Loss 0.0022 Accuracy 1.0000
# Epoch 83 Batch 50 Loss 0.0085 Accuracy 0.9977
# Epoch 83 Batch 100 Loss 0.0073 Accuracy 0.9980
# Epoch 83 Batch 150 Loss 0.0076 Accuracy 0.9979
# Epoch 83 Batch 200 Loss 0.0073 Accuracy 0.9979
# Epoch 83 Batch 250 Loss 0.0069 Accuracy 0.9980
# Epoch 83 Batch 300 Loss 0.0066 Accuracy 0.9981
# Epoch 83 Batch 350 Loss 0.0065 Accuracy 0.9981
# Epoch 83 Loss 0.0062 Accuracy 0.9982
# Time taken for 1 epoch: 22.902923583984375 secs
#
# Epoch 84 Batch 0 Loss 0.0007 Accuracy 1.0000
# Epoch 84 Batch 50 Loss 0.0077 Accuracy 0.9978
# Epoch 84 Batch 100 Loss 0.0073 Accuracy 0.9979
# Epoch 84 Batch 150 Loss 0.0082 Accuracy 0.9976
# Epoch 84 Batch 200 Loss 0.0080 Accuracy 0.9977
# Epoch 84 Batch 250 Loss 0.0074 Accuracy 0.9979
# Epoch 84 Batch 300 Loss 0.0073 Accuracy 0.9979
# Epoch 84 Batch 350 Loss 0.0070 Accuracy 0.9980
# Epoch 84 Loss 0.0067 Accuracy 0.9981
# Time taken for 1 epoch: 22.97719383239746 secs
#
# Epoch 85 Batch 0 Loss 0.0039 Accuracy 1.0000
# Epoch 85 Batch 50 Loss 0.0072 Accuracy 0.9981
# Epoch 85 Batch 100 Loss 0.0073 Accuracy 0.9981
# Epoch 85 Batch 150 Loss 0.0084 Accuracy 0.9977
# Epoch 85 Batch 200 Loss 0.0081 Accuracy 0.9978
# Epoch 85 Batch 250 Loss 0.0076 Accuracy 0.9979
# Epoch 85 Batch 300 Loss 0.0072 Accuracy 0.9980
# Epoch 85 Batch 350 Loss 0.0069 Accuracy 0.9981
# Saving checkpoint for epoch 85 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-17
# Epoch 85 Loss 0.0066 Accuracy 0.9982
# Time taken for 1 epoch: 23.052863359451294 secs
#
# Epoch 86 Batch 0 Loss 0.0176 Accuracy 0.9949
# Epoch 86 Batch 50 Loss 0.0090 Accuracy 0.9978
# Epoch 86 Batch 100 Loss 0.0096 Accuracy 0.9976
# Epoch 86 Batch 150 Loss 0.0100 Accuracy 0.9972
# Epoch 86 Batch 200 Loss 0.0089 Accuracy 0.9975
# Epoch 86 Batch 250 Loss 0.0083 Accuracy 0.9977
# Epoch 86 Batch 300 Loss 0.0078 Accuracy 0.9978
# Epoch 86 Batch 350 Loss 0.0075 Accuracy 0.9978
# Epoch 86 Loss 0.0072 Accuracy 0.9979
# Time taken for 1 epoch: 22.91438937187195 secs
#
# Epoch 87 Batch 0 Loss 0.0028 Accuracy 1.0000
# Epoch 87 Batch 50 Loss 0.0072 Accuracy 0.9982
# Epoch 87 Batch 100 Loss 0.0072 Accuracy 0.9981
# Epoch 87 Batch 150 Loss 0.0074 Accuracy 0.9980
# Epoch 87 Batch 200 Loss 0.0073 Accuracy 0.9980
# Epoch 87 Batch 250 Loss 0.0075 Accuracy 0.9980
# Epoch 87 Batch 300 Loss 0.0071 Accuracy 0.9981
# Epoch 87 Batch 350 Loss 0.0066 Accuracy 0.9982
# Epoch 87 Loss 0.0063 Accuracy 0.9983
# Time taken for 1 epoch: 22.90792989730835 secs
#
# Epoch 88 Batch 0 Loss 0.0006 Accuracy 1.0000
# Epoch 88 Batch 50 Loss 0.0072 Accuracy 0.9981
# Epoch 88 Batch 100 Loss 0.0072 Accuracy 0.9981
# Epoch 88 Batch 150 Loss 0.0079 Accuracy 0.9978
# Epoch 88 Batch 200 Loss 0.0072 Accuracy 0.9980
# Epoch 88 Batch 250 Loss 0.0067 Accuracy 0.9981
# Epoch 88 Batch 300 Loss 0.0066 Accuracy 0.9982
# Epoch 88 Batch 350 Loss 0.0064 Accuracy 0.9982
# Epoch 88 Loss 0.0062 Accuracy 0.9983
# Time taken for 1 epoch: 23.0244300365448 secs
#
# Epoch 89 Batch 0 Loss 0.0006 Accuracy 1.0000
# Epoch 89 Batch 50 Loss 0.0088 Accuracy 0.9975
# Epoch 89 Batch 100 Loss 0.0081 Accuracy 0.9975
# Epoch 89 Batch 150 Loss 0.0082 Accuracy 0.9976
# Epoch 89 Batch 200 Loss 0.0086 Accuracy 0.9976
# Epoch 89 Batch 250 Loss 0.0080 Accuracy 0.9978
# Epoch 89 Batch 300 Loss 0.0075 Accuracy 0.9979
# Epoch 89 Batch 350 Loss 0.0073 Accuracy 0.9980
# Epoch 89 Loss 0.0070 Accuracy 0.9980
# Time taken for 1 epoch: 22.988215923309326 secs
#
# Epoch 90 Batch 0 Loss 0.0031 Accuracy 1.0000
# Epoch 90 Batch 50 Loss 0.0072 Accuracy 0.9978
# Epoch 90 Batch 100 Loss 0.0066 Accuracy 0.9979
# Epoch 90 Batch 150 Loss 0.0069 Accuracy 0.9979
# Epoch 90 Batch 200 Loss 0.0070 Accuracy 0.9979
# Epoch 90 Batch 250 Loss 0.0066 Accuracy 0.9980
# Epoch 90 Batch 300 Loss 0.0064 Accuracy 0.9981
# Epoch 90 Batch 350 Loss 0.0062 Accuracy 0.9982
# Saving checkpoint for epoch 90 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-18
# Epoch 90 Loss 0.0061 Accuracy 0.9982
# Time taken for 1 epoch: 23.05109214782715 secs
#
# Epoch 91 Batch 0 Loss 0.0013 Accuracy 1.0000
# Epoch 91 Batch 50 Loss 0.0078 Accuracy 0.9980
# Epoch 91 Batch 100 Loss 0.0076 Accuracy 0.9980
# Epoch 91 Batch 150 Loss 0.0071 Accuracy 0.9980
# Epoch 91 Batch 200 Loss 0.0065 Accuracy 0.9982
# Epoch 91 Batch 250 Loss 0.0062 Accuracy 0.9983
# Epoch 91 Batch 300 Loss 0.0059 Accuracy 0.9983
# Epoch 91 Batch 350 Loss 0.0058 Accuracy 0.9984
# Epoch 91 Loss 0.0056 Accuracy 0.9984
# Time taken for 1 epoch: 22.958954334259033 secs
#
# Epoch 92 Batch 0 Loss 0.0143 Accuracy 0.9975
# Epoch 92 Batch 50 Loss 0.0073 Accuracy 0.9979
# Epoch 92 Batch 100 Loss 0.0077 Accuracy 0.9979
# Epoch 92 Batch 150 Loss 0.0070 Accuracy 0.9981
# Epoch 92 Batch 200 Loss 0.0069 Accuracy 0.9981
# Epoch 92 Batch 250 Loss 0.0064 Accuracy 0.9982
# Epoch 92 Batch 300 Loss 0.0065 Accuracy 0.9982
# Epoch 92 Batch 350 Loss 0.0062 Accuracy 0.9983
# Epoch 92 Loss 0.0059 Accuracy 0.9984
# Time taken for 1 epoch: 22.931148529052734 secs
#
# Epoch 93 Batch 0 Loss 0.0007 Accuracy 1.0000
# Epoch 93 Batch 50 Loss 0.0100 Accuracy 0.9978
# Epoch 93 Batch 100 Loss 0.0090 Accuracy 0.9978
# Epoch 93 Batch 150 Loss 0.0084 Accuracy 0.9979
# Epoch 93 Batch 200 Loss 0.0079 Accuracy 0.9980
# Epoch 93 Batch 250 Loss 0.0072 Accuracy 0.9982
# Epoch 93 Batch 300 Loss 0.0070 Accuracy 0.9982
# Epoch 93 Batch 350 Loss 0.0069 Accuracy 0.9982
# Epoch 93 Loss 0.0066 Accuracy 0.9982
# Time taken for 1 epoch: 22.940627574920654 secs
#
# Epoch 94 Batch 0 Loss 0.0094 Accuracy 0.9975
# Epoch 94 Batch 50 Loss 0.0069 Accuracy 0.9981
# Epoch 94 Batch 100 Loss 0.0073 Accuracy 0.9980
# Epoch 94 Batch 150 Loss 0.0073 Accuracy 0.9979
# Epoch 94 Batch 200 Loss 0.0071 Accuracy 0.9979
# Epoch 94 Batch 250 Loss 0.0065 Accuracy 0.9981
# Epoch 94 Batch 300 Loss 0.0063 Accuracy 0.9982
# Epoch 94 Batch 350 Loss 0.0059 Accuracy 0.9983
# Epoch 94 Loss 0.0056 Accuracy 0.9983
# Time taken for 1 epoch: 22.90430474281311 secs
#
# Epoch 95 Batch 0 Loss 0.0056 Accuracy 0.9975
# Epoch 95 Batch 50 Loss 0.0065 Accuracy 0.9980
# Epoch 95 Batch 100 Loss 0.0060 Accuracy 0.9982
# Epoch 95 Batch 150 Loss 0.0066 Accuracy 0.9980
# Epoch 95 Batch 200 Loss 0.0066 Accuracy 0.9981
# Epoch 95 Batch 250 Loss 0.0060 Accuracy 0.9982
# Epoch 95 Batch 300 Loss 0.0060 Accuracy 0.9983
# Epoch 95 Batch 350 Loss 0.0058 Accuracy 0.9984
# Saving checkpoint for epoch 95 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-19
# Epoch 95 Loss 0.0056 Accuracy 0.9984
# Time taken for 1 epoch: 23.106310844421387 secs
#
# Epoch 96 Batch 0 Loss 0.0028 Accuracy 1.0000
# Epoch 96 Batch 50 Loss 0.0071 Accuracy 0.9980
# Epoch 96 Batch 100 Loss 0.0063 Accuracy 0.9981
# Epoch 96 Batch 150 Loss 0.0061 Accuracy 0.9981
# Epoch 96 Batch 200 Loss 0.0063 Accuracy 0.9982
# Epoch 96 Batch 250 Loss 0.0058 Accuracy 0.9983
# Epoch 96 Batch 300 Loss 0.0055 Accuracy 0.9984
# Epoch 96 Batch 350 Loss 0.0055 Accuracy 0.9985
# Epoch 96 Loss 0.0054 Accuracy 0.9985
# Time taken for 1 epoch: 22.95907187461853 secs
#
# Epoch 97 Batch 0 Loss 0.0009 Accuracy 1.0000
# Epoch 97 Batch 50 Loss 0.0064 Accuracy 0.9984
# Epoch 97 Batch 100 Loss 0.0062 Accuracy 0.9984
# Epoch 97 Batch 150 Loss 0.0069 Accuracy 0.9982
# Epoch 97 Batch 200 Loss 0.0068 Accuracy 0.9981
# Epoch 97 Batch 250 Loss 0.0066 Accuracy 0.9981
# Epoch 97 Batch 300 Loss 0.0066 Accuracy 0.9982
# Epoch 97 Batch 350 Loss 0.0061 Accuracy 0.9983
# Epoch 97 Loss 0.0060 Accuracy 0.9983
# Time taken for 1 epoch: 23.017319202423096 secs
#
# Epoch 98 Batch 0 Loss 0.0009 Accuracy 1.0000
# Epoch 98 Batch 50 Loss 0.0081 Accuracy 0.9977
# Epoch 98 Batch 100 Loss 0.0078 Accuracy 0.9978
# Epoch 98 Batch 150 Loss 0.0074 Accuracy 0.9979
# Epoch 98 Batch 200 Loss 0.0072 Accuracy 0.9980
# Epoch 98 Batch 250 Loss 0.0065 Accuracy 0.9981
# Epoch 98 Batch 300 Loss 0.0061 Accuracy 0.9983
# Epoch 98 Batch 350 Loss 0.0058 Accuracy 0.9984
# Epoch 98 Loss 0.0055 Accuracy 0.9984
# Time taken for 1 epoch: 22.991645097732544 secs
#
# Epoch 99 Batch 0 Loss 0.0036 Accuracy 0.9975
# Epoch 99 Batch 50 Loss 0.0076 Accuracy 0.9976
# Epoch 99 Batch 100 Loss 0.0069 Accuracy 0.9980
# Epoch 99 Batch 150 Loss 0.0070 Accuracy 0.9980
# Epoch 99 Batch 200 Loss 0.0067 Accuracy 0.9980
# Epoch 99 Batch 250 Loss 0.0062 Accuracy 0.9982
# Epoch 99 Batch 300 Loss 0.0059 Accuracy 0.9982
# Epoch 99 Batch 350 Loss 0.0057 Accuracy 0.9983
# Epoch 99 Loss 0.0055 Accuracy 0.9984
# Time taken for 1 epoch: 22.963005304336548 secs
#
# Epoch 100 Batch 0 Loss 0.0056 Accuracy 0.9975
# Epoch 100 Batch 50 Loss 0.0070 Accuracy 0.9980
# Epoch 100 Batch 100 Loss 0.0078 Accuracy 0.9978
# Epoch 100 Batch 150 Loss 0.0076 Accuracy 0.9979
# Epoch 100 Batch 200 Loss 0.0071 Accuracy 0.9979
# Epoch 100 Batch 250 Loss 0.0067 Accuracy 0.9981
# Epoch 100 Batch 300 Loss 0.0064 Accuracy 0.9982
# Epoch 100 Batch 350 Loss 0.0060 Accuracy 0.9983
# Saving checkpoint for epoch 100 at /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/right_sliding_13_sliding_11/train/ckpt-20
# Epoch 100 Loss 0.0058 Accuracy 0.9983
# Time taken for 1 epoch: 23.24339485168457 secs

# %%
 train_accuracy.result()
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.99833304>

# %%
# code for reloading checkpoints
gdrive_checkpoints = "/gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/"
checkpoint_path = gdrive_checkpoints + "base_sliding_11_window/train"
ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)
#checkpoint_path = './checkpoints/right_window_sliding_7_sliding_11_again/train'
latest = tf.train.latest_checkpoint(checkpoint_path)
print(latest)
ckpt.restore(latest)
# Out:
# /gdrive/MyDrive/ywl_transformer/second_randomized/checkpoints/base_sliding_11_window/train/ckpt-20

# %%
# evaluation function; derived in part from TensorFlow documentation page:
def evaluate_test(test_data):
  accuracies = []
  bleu_real = []
  bleu_pred = []
  wer_scores = []
  for (inp, tar) in test_data:
    input_ = tf.expand_dims(inp, 0) 
    #print(input_)
 
    decoder_input = [total_vocab['<start>']]
    output = tf.cast(tf.expand_dims(decoder_input, 0), tf.int64)
    #print(output)
    #print(type(output))
 
    scorable_output = None
    for i in range(OUTPUT_LEN):
      enc_padding_mask, combined_mask, dec_padding_mask = create_masks(
          input_, output)
      #print(inp)
      predictions, attention_weights = transformer(input_,
                                                   output,
                                                   False,
                                                   enc_padding_mask,
                                                   combined_mask,
                                                   dec_padding_mask)
      #print(type(predictions))
      predictions = predictions[:, -1:, :]
 
      predicted_id = tf.argmax(predictions, axis=-1)
      #print(predicted_id)
 
      output = tf.concat([output, predicted_id], axis=-1)
 
      if predicted_id == total_vocab['<end>']:
        break
 
    #print(output)
    scorable_output = tf.squeeze(output, axis=0)
    print("Actual: {}".format(' '.join(inv_total_vocab[i] for i in tar.numpy())))
    print("Predicted: {}".format(' '.join(inv_total_vocab[i] for i in scorable_output.numpy())))
 
    target_scorable = np.array([i for i in tar.numpy() if i not in [0, 1779, 1780]])
    #print("target:", target_scorable)
    pred_scorable = np.array([i for i in scorable_output.numpy() if i not in [0, 1779, 1780]])
    #print("predicted:", pred_scorable)
 
    bleu_real.append([target_scorable.tolist()])
    bleu_pred.append(pred_scorable.tolist())
 
    # if target and predicted are different lengths, then need to pad here
    if target_scorable.shape[0] != pred_scorable.shape[0]:
      if target_scorable.shape[0] > pred_scorable.shape[0]:
        diff = target_scorable.shape[0] - pred_scorable.shape[0]
        pred_scorable = np.concatenate((pred_scorable, np.zeros((diff,), dtype=np.int32)))
      else:
        diff = pred_scorable.shape[0] - target_scorable.shape[0]
        target_scorable = np.concatenate((target_scorable, np.zeros((diff,), dtype=np.int32)))
 
    target_scorable = tf.convert_to_tensor(target_scorable)
    pred_scorable = tf.convert_to_tensor(pred_scorable)
 
    acc = test_accuracy_function(target_scorable, pred_scorable)
    accuracies.append(acc)
 
    wer_out = wer(target_scorable, pred_scorable)
    wer_scores.append(wer_out/len(target_scorable))
  
  return np.mean(np.asarray(accuracies)), test_bleu_function(bleu_real, bleu_pred), np.mean(np.asarray(wer_scores))

# %%
from nltk.translate.bleu_score import corpus_bleu

# %%
# BLEU score function
def test_bleu_function(real, pred):
  # real and pred here must be numpy
  bleu_1 = corpus_bleu(real, pred, weights=(1.0,))
  bleu_2 = corpus_bleu(real, pred, weights=(0.5, 0.5))
  bleu_3 = corpus_bleu(real, pred, weights=(0.33, 0.33, 0.33))
  bleu_4 = corpus_bleu(real, pred, weights=(0.25, 0.25, 0.25, 0.25))
  return (bleu_1, bleu_2, bleu_3, bleu_4)

# %%
# accuracy function, from TensorFlow documentation page
def test_accuracy_function(real, pred):
  accuracies = tf.equal(real, pred)
  
  mask = tf.math.logical_not(tf.math.equal(real, 0))
  accuracies = tf.math.logical_and(mask, accuracies)
 
  accuracies = tf.cast(accuracies, dtype=tf.float32)
  mask = tf.cast(mask, dtype=tf.float32)
  return tf.reduce_sum(accuracies)/tf.reduce_sum(mask)

# %%
# Word Error Rate calculation function
# published on: https://martin-thoma.com/word-error-rate-calculation/
def wer(r, h):
    """
    Calculation of WER with Levenshtein distance.
 
    Works only for iterables up to 254 elements (uint8).
    O(nm) time ans space complexity.
 
    Parameters
    ----------
    r : list
    h : list
 
    Returns
    -------
    int
 
    Examples
    --------
    >>> wer("who is there".split(), "is there".split())
    1
    >>> wer("who is there".split(), "".split())
    3
    >>> wer("".split(), "who is there".split())
    3
    """
    # initialisation
    import numpy
 
    d = numpy.zeros((len(r) + 1) * (len(h) + 1), dtype=numpy.uint8)
    d = d.reshape((len(r) + 1, len(h) + 1))
    for i in range(len(r) + 1):
        for j in range(len(h) + 1):
            if i == 0:
                d[0][j] = j
            elif j == 0:
                d[i][0] = i
 
    # computation
    for i in range(1, len(r) + 1):
        for j in range(1, len(h) + 1):
            if r[i - 1] == h[j - 1]:
                d[i][j] = d[i - 1][j - 1]
            else:
                substitution = d[i - 1][j - 1] + 1
                insertion = d[i][j - 1] + 1
                deletion = d[i - 1][j] + 1
                d[i][j] = min(substitution, insertion, deletion)
 
    return d[len(r)][len(h)]

# %%
# run evaluation
evaluate_test(test_dataset)
# Out:
# Actual: <start> limik' xaya: traw , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> limik' xo: traw , <end>
# Actual: <start> 'alwutr' no:chro' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'alwutr' no:chro' , <end>
# Actual: <start> ye:tr'aw ma:gin pana: 'amak' hew'ta: , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> ye:tr'aw ma:gin pana: 'amak' hew'ta: , <end>
# Actual: <start> 'ama' ye:t' pana: 'amak' tr'ama' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' yet' pana: 'amak' tawtra: , <end>
# Actual: <start> mani' 'amin p'ow , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mani' 'aman tripin , <end>
# Actual: <start> 'ama' limik' tisi 'amin 'olol , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' limik' tisi 'amin 'olol , <end>
# Actual: <start> 'ama' [unknown] [unknown] , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tran k'o'o , <end>
# Actual: <start> 'ama' [unknown] [unknown] p'ow tra 'olol , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' toyon tran bonoy tra 'olol , <end>
# Actual: <start> 'ama' tisi tr'ama' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' di'ishr tra 'ama' , <end>
# Actual: <start> pichriw tran 'olol , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> pichriw tran 'olol , <end>
# Actual: <start> 'ama' [unknown] ma' gidax limik' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' wiyi ma' gidax limik' , <end>
# Actual: <start> mi'in na'ak' ta:na … . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> [unknown] taxa: . <end>
# Actual: <start> 'ama' 'amak' pana: ye:t' moxlo' ga:'ina , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' 'amak' pana: ye:t' moxlo' ga:'ina , <end>
# Actual: <start> ta:na tra ma' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> ta:na tra ma' , <end>
# Actual: <start> [unknown] logow , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> [unknown] ta:na lo:l'o: , <end>
# Actual: <start> 'ama' mak' traw pana: ye:t' yow tr'ama' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' makwa ta:na yet' yow traw ma'a , <end>
# Actual: <start> 'ama' 'utru 'amin [unknown] limik' ta'an' bonoy 'amak' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' 'utru 'amin yow limik' tran bonoy 'ama' , <end>
# Actual: <start> 'a:n'i wiyi wiyi tran , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'a:n'i wiyi wiyi tran , <end>
# Actual: <start> mec' limik' no:chro' 'amin , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mec' limik' no:chro' 'amin , <end>
# Actual: <start> 'a:n'i wiyi wiyi tran , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'a:n'i wiyi wiyi tran , <end>
# Actual: <start> traw tran tran tr'ama' logow tran , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> ta:watr tran tran 'ama' logow xinic' , <end>
# Actual: <start> ta:na tra:nit yiy'ca:/ , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> ta:na wiyi tra:nit yo'ke: , <end>
# Actual: <start> ye:t' 'amin wilshrin xapa' ma:xa , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> ye:t' 'amin wilshrin xa:pal ma:xa , <end>
# Actual: <start> no:chro' 'amin , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> no:chro' 'amin , <end>
# Actual: <start> xaya: tran dimaha' 'amin , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> xaya: tran dimaha' 'amin , <end>
# Actual: <start> 'ama' hiyam wa' ta:na 'ama' [unknown] 'amin no:chro' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' hiyam wa' ta:na nim [unknown] 'amin no:chro' , <end>
# Actual: <start> 'ama' tran tisi [unknown] xa:pal , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tran tisi ke:nit wa' , <end>
# Actual: <start> 'ama' tran po:su , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tran po:su , <end>
# Actual: <start> 'ama' traw tisi 'alwutr' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' traw tisi 'alwutr' , <end>
# Actual: <start> wasto na' wo:'uy wiyi 'alwutr' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> wa'ashrta' wa' 'e:dil wiyi 'alwutr' , <end>
# Actual: <start> ha:nuk ma:wo: wiyi , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> ha:nuk ma'an wo:'uy wiyi , <end>
# Actual: <start> logow mam tra moxlo' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> logow mam traw mo:xol , <end>
# Actual: <start> shril'i min kin po:lut . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> shrilit' min gi' [unknown] . <end>
# Actual: <start> shril'i 'amin po:lut hiyam modrk'iwik hi' [unknown] ta:na , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> shril'i 'amin [unknown] hiyam mo:tr'ak' ta:na , <end>
# Actual: <start> hiyo'uk mak' ta:na wiyi tran limik' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hiyo'uk mak' ta:na wiyi tran limik' , <end>
# Actual: <start> mi'in mak' pana: ye:t' yow moxlo' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mi'in mak' pana: ye:t' moxlo' , <end>
# Actual: <start> 'ohom batr ma' tran he'ca: , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ohom batr ma' tran he'ca: , <end>
# Actual: <start> hamna' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hamna' , <end>
# Actual: <start> bonoy 'amin witeb ga'e:ni , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> bonoy 'amin wichribhay ga'e:ni , <end>
# Actual: <start> 'ama' mak' tra pana: , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' mak' tran p'a'an , <end>
# Actual: <start> mi'in 'amak' boy'e:tr'a:/ , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> [unknown] boy'e:tr'a:/ , <end>
# Actual: <start> pana: gidax ma' hiy'aw'tra' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> pana: gidax ma' hiyam [unknown] , <end>
# Actual: <start> wiyi tran hamna' . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> wiyi tran hamna' . <end>
# Actual: <start> mi'in na' he:zhi' la:na min 'ilik toyon , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mi'in na' 'e:dil 'ama' mi'in 'ilik toyon , <end>
# Actual: <start> mi'in toyon 'ilik limik' . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mi'in toy'no' 'ilik limik' . <end>
# Actual: <start> hi' ma:xa ma' wo:'uy wiyi tran limik' 'ohom wiyi hamna' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hi' ma:xa wo:'uy wiyi tran limik' 'ohom wiyi hamna' , <end>
# Actual: <start> no:n'o' [unknown] ga:'ina hamna' witeb , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> no:n'o' mak' [unknown] tra 'amin wichribhay , <end>
# Actual: <start> hiyam tawin wo:'uy 'amam triymi traw mak' triymi ta:na , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hiyam tawin traw wo:'uy 'ama' traw mak' hi' tisi , <end>
# Actual: <start> 'ama' 'opo:t limik' 'ama' tisi 'amin 'entram , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' 'opo:t limik' 'ama' tisi 'amin tri' , <end>
# Actual: <start> k'o'o tran 'oshrit 'entram , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> k'o'o tran 'oshrit , <end>
# Actual: <start> 'ama' k'o'o tran [unknown] wiyi 'oshrit , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' k'o'o tran mi'in na' 'ohyo: , <end>
# Actual: <start> | wa'ashrta' 'ashr 'insis 'amin tre:kin , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> [unknown] 'ashr 'insis' 'amin de:yi , <end>
# Actual: <start> [unknown] [unknown] ta:na wo:'uy hamna' bim'tran'a' 'amak' traw lol'o , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'amin dik'naw wotro 'aman bim'tran'a' bumuk' traw lo:l'o: , <end>
# Actual: <start> 'amingin wo:'uy , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'amingin wo:'uy , <end>
# Actual: <start> 'ama' tra tre:xal , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tra tre:xal , <end>
# Actual: <start> hiyam 'amak' wa' ta:na , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> [unknown] 'amak' ta:na , <end>
# Actual: <start> shra:lak' 'amam triymi , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> sha:lak' 'ama' triymi , <end>
# Actual: <start> wiyi tran 'alwutr' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> wiyi tran 'alwutr' , <end>
# Actual: <start> 'ohom wiyi limik' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ohom wiyi limik' , <end>
# Actual: <start> pichriw [unknown] , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> pichriw makwihi' , <end>
# Actual: <start> shra:lak' 'amam [interj] . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> sha:lak' mam <end>
# Actual: <start> wiyi 'alwutr' 'insis wiyi limik' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> wiyi 'alwutr' 'insis' wiyi limik' , <end>
# Actual: <start> 'ama' tisi 'amin k'umayha' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tisi 'amin [unknown] , <end>
# Actual: <start> po:su tran , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> po:su tran , <end>
# Actual: <start> 'ama' dab shra:lak' hamna' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' dab sha:lak' hamna' , <end>
# Actual: <start> hiyuk ma' hiy'aw'tra' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hiyuk ma' hiy'aw'tra:/ , <end>
# Actual: <start> 'ohom traw . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ohom traw . <end>
# Actual: <start> koshron tran , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> koshron tran , <end>
# Actual: <start> 'ama' bo:do hamna' min kin be:ni c'uyo: [unknown] hiyo'uk ta:na hiy'aw'tra' tra 'amam [unknown] xata , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' 'opo:t hamna' min gi' de:yi tro:k'o 'ama' yow traw 'ama' hiyam taxa: , <end>
# Actual: <start> hiyam bilishr 'amin kinip , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hiyam bilishr 'amin kinip , <end>
# Actual: <start> 'ama:mikwa damna: ham'wiyi , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' makwa ta:na xa:mi wiyi , <end>
# Actual: <start> 'ama' 'amak' taxa: , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' 'amak' taxa: , <end>
# Actual: <start> tra [unknown] 'ama:mikwa ki 'amin ham'wiyi . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> tra tawin 'ama:mikwa ki 'amin yah min wiyi . <end>
# Actual: <start> bis na' mam wiyi xata [unknown] wiyi 'amin no:chro' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> bis na' mam wiyi taxa: mi'in na' mam no:chro' , <end>
# Actual: <start> 'ama' yow 'ama:mikwa ham'wiyi , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' yow 'ama:mikwa hamna' , <end>
# Actual: <start> me:k'i na' ma:mikwa , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> [unknown] makwa , <end>
# Actual: <start> 'ama' tisi limik' 'amin 'utru . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tisi limik' 'ama' 'amin 'utru . <end>
# Actual: <start> 'ama' tran [unknown] go:bin 'amin sama' 'ama' 'amak traw hulo:shr 'angi' ma' hiyam yehe:sin wiyi [unknown] 'amin , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tran giw'iw'wiyi 'amin sama' 'ama' 'amak' traw hulo:shr 'abiy tran 'ama' <end>
# Actual: <start> hǫ:hǫ' wiyi [unknown] triymi wiyi 'alwutr' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> [unknown] wiyi yah mak' tre:min , <end>
# Actual: <start> 'ama' batr 'ama:mikwa koshron , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' batr 'ama:mikwa koshron , <end>
# Actual: <start> 'ama' yow ham'wiyi 'ama' batr 'ama:mikwa canum pana: , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' yow ham'wiyi 'ama' batr 'ama:mikwa canum pana: , <end>
# Actual: <start> ham'wiyi , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> ham'wiyi , <end>
# Actual: <start> 'ama' 'alwutr' ha'uk batr ki yow gomwiyi , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' 'alwutr' ha'uk min yo:w gomwiyi , <end>
# Actual: <start> 'ushruk' 'amin wiyi . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ushruk' 'amin wiyi . <end>
# Actual: <start> limik' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> limik' , <end>
# Actual: <start> tsisi' wiyi 'alwutr' tran wiyi , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> tisi wiyi 'alwutr' tran wiyi , <end>
# Actual: <start> 'ama' tisi 'amin tr'o:lo , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tisi 'amin tr'o:lo , <end>
# Actual: <start> tsisi' 'amin 'ushruk' 'ama' ta:witr , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> tsisi' 'amin 'ushruk' 'ama' ta:witr , <end>
# Actual: <start> tri' 'amak' yehe:sin ) . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> tri' 'amak' [unknown] wo:no . <end>
# Actual: <start> mi'in 'amak yow ta:na , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mi'in 'amak' yow ta:na , <end>
# Actual: <start> mi'in 'amak' pana: , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mi'in 'amak' pana: , <end>
# Actual: <start> 'ohom batr ma' witep na' tri' wiyi 'amin no:chro' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ohom batr ma' witibha:chr' 'ipitr wiyi 'amin no:chro' , <end>
# Actual: <start> wa:xal batr mihi' bonoy 'amin ta'an' witep copnig , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> walxo: batr mihi' bonoy 'amin tran witibha:chr' 'ipitr yow Copnig , <end>
# Actual: <start> canum 'ama:mikwa linic' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> canum 'ama:mikwa linic' , <end>
# Actual: <start> kisik' batr wa'ashrta' ma:mikwa tritreya:/ ma:mikwa wiyi 'amin witeb , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> [unknown] wa'ashrta' wa' min tri' yow limik' wiyi 'amin wichribhay , <end>
# Actual: <start> wa'ashrgi he:zhi' toyon , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> wa'ashrgi he:zhi' toyon , <end>
# Actual: <start> ma' [unknown] 'ama' na' la:na hiyam [unknown] 'ohom na' ganaw min 'utru , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> ma' tran 'ama' na' la:na hiyam 'aga:y 'ohom na' 'ohom nihi' , <end>
# Actual: <start> mi'in dab toyon 'utru limik' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mi'in dab toy'no' 'ilik limik' , <end>
# Actual: <start> yow dab la:na mi'in copnig , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> yow dab [unknown] mi'in Copnig , <end>
# Actual: <start> ta:na [unknown] 'amingin wo:'uy 'ama' 'ama:mikwa shroxo yow 'amak' ta'an' wiyi [unknown] 'amak' ta'an' 'amin wo:'uy , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> ta:na [unknown] 'ama' 'ama:mikwa wiyi 'ama' 'ama:mikwa shroxo ye:tr'aw yokoc' taxa: 'ama' 'amak' <end>
# Actual: <start> 'ama' mak' tran tawtra: , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' mak' ta:na ta:witr , <end>
# Actual: <start> 'ama' tawan traw 'amak' tran tsisi' 'o:kun . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tawa:nwiyi traw 'amak' tran tisi so:gon . <end>
# Actual: <start> 'ama' traw pana: kay'iw , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' traw pana: kay'iw , <end>
# Actual: <start> [unknown] . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> batr'in . <end>
# Actual: <start> [unknown] . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> no'om . <end>
# Actual: <start> [unknown] [unknown] tawtra: wiyi , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> [unknown] tawtra: wo:yo , <end>
# Actual: <start> hǫ:hǫ' wiyi limik' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> [unknown] wiyi limik' , <end>
# Actual: <start> wakkiy 'insis , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> wakkiy 'insis , <end>
# Actual: <start> wiyi [unknown] , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> wiyi kay'iw , <end>
# Actual: <start> [unknown] na' tran luk'ul wiyi . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mi'in na' tran luk'ul wiyi . <end>
# Actual: <start> tawtra: tran 'ama' hiyam 'amak' dab mokye:' . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> tawtra: tran 'ama' hiyam 'amak' dab mokiy' . <end>
# Actual: <start> hiyam 'ama:mikwa kay'iw 'abiy xo' hiyam 'aman shro:pin hiyam batr hudu kay'iw , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hiyam makwa kay'iw 'abiy xo: hamna' samaywas hiyam batr hudu kay'iw , <end>
# Actual: <start> taxa: tra 'otr'ow copnig , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> taxa: tra 'otr'ow [unknown] , <end>
# Actual: <start> toyon wiyi , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> toyon wiyi , <end>
# Actual: <start> wac'a wiyi ma'ak' wiyi kay'iw tawtra: may [unknown] wiyi , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> wats'wis mak' wiyi kay'iw tawtra: 'ama' wiyi wiyi , <end>
# Actual: <start> 'ama' mizhna' toyon pana: hiyam 'amino:gun wo:'uy , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' mi'in toyon pana: hiyam' 'amino:gun wo:'uy 'ama' xuno:chru 'a:wuw , <end>
# Actual: <start> hiyam 'amino:gun wo:'uy yow dab taxa: 'otr'ow , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hiyam 'amino:gun wotr'od yow dab taxa: 'otr'ow , <end>
# Actual: <start> [unknown] wiyi taxa: , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> damna: wiyi taxa: , <end>
# Actual: <start> tro:k'o 'ama:minwa , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> tro:k'o 'ama:minwa , <end>
# Actual: <start> 'ama' batr dab kay'iw 'opo:t 'ama' batr tran ma:xa [unknown] 'ama:maw 'ama' batr tawtra: luk'ul , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' batr dab kay'iw 'opo:t 'ama' batr tran 'otix 'ama' batr traw tran logow , <end>
# Actual: <start> hiyam gi' ma' tran ta:na wiyi tran hiy'aw'tra:/ , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hiyam ki tran ta:na wiyi tran hiyam traw , <end>
# Actual: <start> hǫ:hǫ' wiyi kay'iw , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> [unknown] wiyi kay'iw , <end>
# Actual: <start> [unknown] na' tran he:zhi' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> di'ishr na' tran he:zhi' , <end>
# Actual: <start> 'ohom hiyo'uk taxa: wiyi , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ohom hi' taxa: wiyi , <end>
# Actual: <start> 'ama' batr 'amino:gun wasto wo:'uy [unknown] taxa: , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' batr 'amino:gun wa'ashrta' wotro wa'ashrta' [unknown] , <end>
# Actual: <start> tra 'otr'ow , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> tra 'o:tr'u , <end>
# Actual: <start> tawan mi'in 'ama:minwa wa'ashrta' [unknown] . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> tawa:nwiyi mi'in 'ama:mikwa wa'ashrta' boy'o:me: . <end>
# Actual: <start> min [unknown] pana: hiyam tawin , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> min co:pun hiyam ta:na hiyam tawin , <end>
# Actual: <start> mi'in 'ama:minwa [unknown] tro:k'o , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mi'in 'ama:minwa co:pun tri' , <end>
# Actual: <start> mi'in batr wa:xal limik' wak'ak'wiyi , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mi'in batr wa:xal limik' wak'ak'wiyi wiyi , <end>
# Actual: <start> hiyam 'amak' boy'e:tr'a:/ hiyam 'amak' 'ohom hiyo'uk ta:na , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hiyam 'amak' boy'e:tr'a:/ hiyam 'amak' 'ohom hiyo'uk ta:na , <end>
# Actual: <start> kay'iw ta:na hiyam . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> kay'iw ta:na hiyam . <end>
# Actual: <start> boy'e:tr'a:/ , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> boy'e:tr'a:/ , <end>
# Actual: <start> 'ohom gi' mak' na'ashr hiyo'uk ta:na wiyi 'alwutr' na'an no:chro' 'amin limik' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ohom [unknown] hiyuk ta'an' wiyi 'alwutr' tran no:chro' 'amin limik' , <end>
# Actual: <start> mi'in mak' tawtra: nusos wiyi , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mi'in mak' ta:na nusos wiyi , <end>
# Actual: <start> 'ama' 'amak' tra:nit taxa: , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' 'amak' tra:nit taxa: , <end>
# Actual: <start> c'olol lomit . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> c'owo lomit xolom . <end>
# Actual: <start> hiyam 'ama:mikwa dab yawa:l , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hiyam 'ama:mikwa dab yow lagil , <end>
# Actual: <start> kay'iw dab 'abiy tran , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> kay'iw dab wiyi , <end>
# Actual: <start> shroxo tran 'e:man 'otr'ow kin kay'iw wa ta:na da'a'le: , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> shroxo xo: tran he:dam k'o'o kay'iw wiyi ta:na tr'alap , <end>
# Actual: <start> 'ama' traw 'amingin pana: wiyi tran nusos 'amin , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' traw 'amingin pana: wiyi tran nusos 'amin , <end>
# Actual: <start> [unknown] min 'ohom la:na , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> wa c'o:mu wiyi , <end>
# Actual: <start> 'a:n'i [unknown] kin [unknown] hi' wiyi [unknown] na' mam 'e:man , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'amin hiwe:t cawa hi' tri' pana: nim 'e:man 'amin , <end>
# Actual: <start> 'ama' hiyam 'amingin traw yo:w yow dab taxa: 'otr'ow , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' hiyam 'amingin traw yow yow dab taxa: 'otr'ow , <end>
# Actual: <start> hiyam 'amak' dab go:bin xo' lomit yow dab taxa: 'otr'ow , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hiyam 'amak' dab go:bin xo: lomit yow dab taxa: 'otr'ow , <end>
# Actual: <start> traw tro:k'o kin lomit 'ama' traw tr'iwi , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> traw tro:k'o limik' lomit 'ohom traw tri' wiyi , <end>
# Actual: <start> 'ama' tra 'amin [unknown] tra c'olol traw c'o:mu , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tra 'amin nopop tr'o:lo traw c'e:la:lun traw c'o:mu , <end>
# Actual: <start> tra 'amin c'umun . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> tra 'amin c'umun . <end>
# Actual: <start> pana: 'amino:gun tri' kay'iw , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> pana: 'amino:gun tri' kay'iw , <end>
# Actual: <start> 'e:liw 'amin tri' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hoy'le: 'amin tri' , <end>
# Actual: <start> mi'in bine:t yokoc' wa 'ohom watuk tre:xal 'amam toyon pana: tran trik'it' . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mi'in bine:t yokoc' yow 'ohom watuk tre:xal do:so ha:nuk tran tr'ik'i . <end>
# Actual: <start> 'ama' tran batr 'ama:minwa linic' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tran 'ama:minwa linic' , <end>
# Actual: <start> 'ama' [unknown] tran [unknown] mi'in may xata , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' ta:watr mi'in may xata , <end>
# Actual: <start> [unknown] mizhna' hawa'tamuk man xata wiyi di' kay'iw . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> shrilel mit'achr wiyi hawa'tamuk 'aman xata wiyi ki . <end>
# Actual: <start> 'ama' di' canum ye:t' wo:wul 'ama' k'o'o lopitr 'ama' tran mek'i 'ama' dab kay'iw 'ohom dab wiyi nim tran xat , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' di' canum [unknown] 'ama' k'o'o 'oshrit 'ama' tran me:k'i  'ama' dab kay'iw 'ohom dab limik' wilshrin 'amin dab kay'iw 'ohom . <end>
# Actual: <start> wiyi di' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> wiyi di' , <end>
# Actual: <start> na' dab tran c'ixil 'ama' na' tran wi: [unknown] [unknown] , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> na'an dab tran di'ya' 'ama' na'an tran wiyi p'a'an , <end>
# Actual: <start> 'ama' ta:na batr 'ashr wo:wul kay'iw mi'in tra:ni wa:na ye:t' lopitr , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tran batr wo:wul kay'iw mi'in tra:ni wa:na guchrchrun 'olol , <end>
# Actual: <start> 'ama' tra:ni k'o'o 'ama' dab tripin ta:na , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tra:ni k'o'o 'ama' dab tripna' ta:na , <end>
# Actual: <start> 'ama' go:nin . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' go:nin . <end>
# Actual: <start> 'ama' di' wiyi kay'iw hiyam na' mino:gun xat xata . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' di' wiyi kay'iw hiyam nimo:gun xat taxa: . <end>
# Actual: <start> ta:na ma'an hi' xata nim xat wiyi kay'iw , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> ta:na ma'an hi' xata wiyi kay'iw , <end>
# Actual: <start> 'ama' 'ax dab c'owo so:gon kay'iw , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' [unknown] c'owo wiyi xo: so:gon kay'iw , <end>
# Actual: <start> mi'in 'ama:minwa so:gon wa:na , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mi'in 'ama:minwa so:gon wiyi , <end>
# Actual: <start> 'ama' 'ama:minwa ye:tr'aw so:gon wa:na , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' 'ama:minwa ye:tr'aw so:gon wa:na , <end>
# Actual: <start> batr'in 'aman . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> batr bim'tran'a' 'aman . <end>
# Actual: <start> 'ama' 'amino:gun batr'in mi'in 'otr'ow ta:na sa'nac' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' 'amino:gun batr mi'in batr mi'in tran tra:ni ta:na , <end>
# Actual: <start> 'ama' ma:xa ye:t' min tran kay'iw , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' ma:xa ye:t' mi'in ta:na kay'iw , <end>
# ...
# Predicted: <start> 'ama' dik'naw batr tran wo:'uy 'ama' 'aman ta:na wic'et 'ama' traw 'aman 'e:dil <end>
# Actual: <start> ye:t' melaga:nu' taxa: k'ulumc'ay 'ama' [unknown] 'amin [unknown] 'o:kun 'ama' tran wiyi lihim ! 'ama' k'ulumc'ay ta:na . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> ye:t' me:k'i  c'o:mu kay'iw 'ama' [unknown] 'ama' [unknown] 'amino:gun 'ama' tran wiyi limik' ! <end>
# Actual: <start> hiyam nimo:gun traw [unknown] xo: , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hiyam nimo:gun traw wa' xo: , <end>
# Actual: <start> 'ama' melaga:nu' diy'a' na:ninwa wiyi lomit may ta:na ! wiyi dumas taxa: c'uyo: ma' 'ashr [unknown] ta'an' mihi' da'al lomit . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' [unknown] di'ya' na:ninwa wiyi lomit yow may ta:na [unknown] <end>
# Actual: <start> diy'a' shruyna:/ p'a'an lomit . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> diy'a' [unknown] 'ama' lomit . <end>
# Actual: <start> trasin zhu'ba' melaga:nu' bine:t tran melaga:nu' hawye:no'uk 'amin [unknown] 'ohyo: p'a'an . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> trasin zhu'ba' ge:wi limik' bine:t tr'oxil yo:w yo'ke: 'amin shrogol t'uyu . <end>
# Actual: <start> wilshrin na' wiyi [unknown] 'ohyo: . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> wilshrin na' wiyi tran 'ohyo: . <end>
# Actual: <start> diy'a' shruyna:/ ye:tr'aw 'amin baga' shruyna:/ tra:ni 'inya:na' . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> diy'a' [unknown] ye:tr'aw 'amin pa:yax nay guchrchrun t'ihe' limik' . <end>
# Actual: <start> 'ohom 'aman ye:t' taxa: 'inya:na' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ohom 'aman 'e:dil taxa: 'inya:na' , <end>
# Actual: <start> zhu'ba' taxa: canum , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> zhu'ba' taxa: canum , <end>
# Actual: <start> yow zhu'ba' dik'naw . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> yow zhu'ba' dik'naw dab . <end>
# Actual: <start> dumas wa' kew xaya: yo:w zhu'ba' wa' baluw . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> [unknown] wa' kew xaya: yow zhu'ba' . <end>
# Actual: <start> dumas mani' 'amin gawa:yu' yow 'amin p'a'an . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> Téyes mani' 'amin wuk'uy yow 'amin p'a'an . <end>
# Actual: <start> zhu'ba' kisin yokoc' 'ohom 'aman 'insinxo dumas me'zhi' 'aman wiyi [unknown] . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> zhu'ba' kisin yokoc' 'ohom 'aman 'insinxo tam'ay 'ama:mikwa . <end>
# Actual: <start> mikitti moxlo' ga:'ina shrik'iyt'iyp'aw tre:min . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mikitti' moxlo' ga:'ina [unknown] <end>
# Actual: <start> noh'o' tawtra: mikitti wichreb hohliylaw . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> noh'o' tawtra: mikitti' . <end>
# Actual: <start> mikitti wiyi 'amin wichreb traw mihi' laba:y xolom 'ama' ma' tran 'ohom xata tra:nit wilshrin ma' tran taxa: ma' tran 'ama' ma' tran ke:nit c'e:da: . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mikitti' wiyi 'amin wichribhay mi'in lime:k'a:/ lihim 'ama' tran 'ohom xata tra 'amin draxa <end>
# Actual: <start> mikitti wichreb ta:na laba:y 'ama' traw laba:y mani' 'ama' wiyi he:dam traw hulo:shr 'ama' tra:nit hetnit c'e:da: . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mikitti' . <end>
# Actual: <start> 'ama' traw noh'o' ye:tr'aw c'o:mu 'amin po:lut yow 'amin ta'an' tra xolom , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' traw no'od ye:tr'aw c'amis 'amin po:lum 'ama' pana: tran xolom , <end>
# Actual: <start> ye:tr'aw xotr'oy nadadwiyi . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> ye:tr'aw xotr'oy xata . <end>
# Actual: <start> 'ama' mikitti taxa: 'ohyo: 'amin wichreb . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' mikitti' taxa: 'ohyo: 'amin wichribhay . <end>
# Actual: <start> tw̥ wiyi mikitti . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> tawtra: wo:yo wiyi mikitti' . <end>
# Actual: <start> ha'zhaxom mikitti bok'o pa:yax xolom t'ap't'ap' . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> ha'zhaxom mikitti' hi' go:bin xo: limik' da:ba' t'ap' . <end>
# Actual: <start> 'ama' tran ta:na 'amin tri' 'ama' tran xaya: k'aw'o:dashr 'ama' tran wiyi tromo . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tran ta:na 'amin tri' 'ama' tran xaya: kew 'ama' tran wiyi . <end>
# Actual: <start> tawin hiyam' tr'aytr'ay 'ilik , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> tawin hiyam' tra'ashr 'ilik , <end>
# Actual: <start> 'ama' mikitti lets'a tran witeb 'ama' tran wiyi 'atral 'ama' hiyam traw xo: witeb . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' mikitti' tran wiyi tran wic'et 'ama' tran wiyi shril'i . <end>
# Actual: <start> 'ama' bo:hutr' tra no:to' . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' bo:hutr' tra no:to' . <end>
# Actual: <start> 'ama' nopop 'amin tr'alap yow 'amin t'uyos hoy'le: . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' nopop 'amin tr'alap tra:ni yow 'amin no:chro' xotr'oy . <end>
# Actual: <start> hiyam bo:hutr' bine:t mikitti watuk 'amin nopop yow 'amin no'om . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hiyam bo:hutr' mi'in kin mikitti' 'amin nopop yo:w 'amin no'om . <end>
# Actual: <start> 'ohom tran de:yaw do:so 'ohyo: wilshrin ta'an' tran 'ashr dik'naw do:so . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ohom tran di'ya' do:so 'ohyo: wilshrin ta'an' tran k'ashryin . <end>
# Actual: <start> 'ama' tra:nit do:so mikitti ta:na tawtra: noh'o' . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tra:nit do:so mikitti' ta:na ta:witr tran noh'o' . <end>
# Actual: <start> ta:na lomit 'amcaw delhol . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> ta:na lomit 'ohom traw do:lul . <end>
# Actual: <start> tr'elsi' xo: dab tripin lomit , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> tre:lis xo: dab tripna' limik' , <end>
# Actual: <start> tra:nit wo:sayna: 'ama' bo:hutr' lomit 'amin wo:sayna: . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> tra:nit wo:sayna: 'ama' bo:hutr' lo:l'o: 'amin wichribhay . <end>
# Actual: <start> mikitti 'e:nas xo: p'e:p'at'iw tran lomit . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> mikitti' tran [unknown] p'umu lopitr tran limik' . <end>
# Actual: <start> 'ama' tra noh'o' tisi 'ama' traw gidiw silel . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tra noh'o' tisi 'ama' traw gidiw c'umun . <end>
# Actual: <start> wakkiy tripni' tra noh'o' . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> wakkiy tripni' tra noh'o' . <end>
# Actual: <start> wak'ak'wiyi wiyi tran mikitti 'e:nas shril'i 'angi' min tre:yiy xo: shrilishr . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> wak'ak'wiyi wiyi tran mikitti' 'ama' shril'i 'amingin mokiy' xo: shril'i . <end>
# Actual: <start> 'ama' wak'ak'wiyi tra noh'o' 'ama' mikitti 'e:nas wiyi shrilit' nim sama' ! 'ama' go:bin hiyam noh'o' go:bin totr tsisi' 'amin 'ushruk' , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' wak'ak'wiyi k'o'o tra no'om 'ama' ma' kew shril'i di' mo:xol hiyam nimo:gun trasinwa zhu'ba' yokoc' di'ya' 'ohom 'aman tran co:pun . <end>
# Actual: <start> 'ama' wiyi tisi 'amin dik'naw 'ama' tran tawtra: c'o:du 'ama' tran wiyi bilen' 'amin c'uluy 'ama' tran ta:na tri' 'amin , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' wiyi tisi 'amin dik'naw 'ama' tran tawtra: 'ama' tran wiyi 'amin c'umun <end>
# Actual: <start> 'ama' tran xaya: mikitti hibe:y . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tran xaya: mikitti' . <end>
# Actual: <start> 'ama' wiyi ta:na tri' 'ama' wiyi mikitti hashra:k'in na' . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' wiyi ta:na tri' 'ama' wiyi mikitti' ha'uk min k'e:xa' . <end>
# Actual: <start> 'ama' tran wa:na 'ilik' 'ac' 'amin xo: wilshrin mikitti wiyi ki dab dotr'i' . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tran wa:na 'ilik' 'amin xo: 'amin xo: wik' triymi wiyi ki <end>
# Actual: <start> 'ama' tra:nit tisi mikitti 'ama' 'ipitr tran 'ilik' 'ama' traw c'uyo: 'ac' . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tra:nit tisi mikitti' 'ama' 'ipitr tran 'ilik' 'ama' traw c'umun . <end>
# Actual: <start> 'ama' tra:ni tran taxa: . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tra:ni tran taxa: . <end>
# Actual: <start> wilshrin tran 'awa:tr . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> wilshrin tran tr'aw'a . <end>
# Actual: <start> lihim ta:na , <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> limik' ta:na , <end>
# Actual: <start> hibe:y 'ine:sa: 'ilik' ! ki dab dotr'i' . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hi' bok'o 'ilik sidi wil ! tra 'entram . <end>
# Actual: <start> 'ama' tisi mikitti 'ama' yow traw c'uyo: 'ama' batr tran taxa: . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' tisi mikitti' 'ama' yow traw tr'uktr'ukwiyi 'ama' batr tran taxa: . <end>
# Actual: <start> dotr'i' dab ki lihim ! hibe:y 'ine:sa: wiyi tran . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> dotr''in da:ba' ki limik' ! hibe:y wiyi tran . <end>
# Actual: <start> 'ama' ta:na hibe:y mikitti 'ilik' 'ama' traw shril'i tra:'in noh'o' c'uluy . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' ta:na dibiknizh mihi' 'ilik' 'ama' traw shril'i mani' hay'al . <end>
# Actual: <start> 'ama' hudu wa:tinuk c'uluy 'ama' wakkiy hiyt'iwla:/ . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> 'ama' hudu wa:tinuk c'uluy 'ama' wakkiy dik'naw 'ama:mikwa . <end>
# Actual: <start> hiyt'iwla:/ me'zhi' 'amin 'e:nas tawtra: noh'o' ki 'amin tra no'om tawtra: . <end> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad> <pad>
# Predicted: <start> hi' wa'a:'in ke:ni mihi' tran tawtra: noh'o' ki 'amin tra no'om . <end>
# (0.63602096,
#  (0.7216080571824429,
#   0.6153992604753744,
#   0.5148178235898135,
#   0.429310038760814),
#  0.30638909932682257)

# %%
# copy locally saved files if necessary
# !cp -r /content/second_randomized/* /gdrive/MyDrive/ywl_transformer/second_randomized/
